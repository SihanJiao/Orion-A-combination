3]","mtarg1[-81.66,-140.3]","mtarg1[-81.66,-109.12]","mtarg1[-117.95,-109.12]","mtarg1[-154.24,-109.12]","mtarg1[-154.24,-77.94]","mtarg1[-117.95,-77.94]","mtarg1[-81.66,-77.94]","mtarg1[-136.09,-46.77]","mtarg1[-172.38,-46.77]","mtarg1[-154.23,-15.59]","mtarg1[-190.52,15.59]","mtarg1[-145.18,-311.77]","mtarg1[-108.88,-311.77]","mtarg1[-72.59,-311.77]","mtarg1[-108.88,-280.59]","mtarg1[-72.59,-280.59]","mtarg1[-72.59,-249.42]","mtarg1[-108.88,-249.42]","mtarg1[-181.47,-249.42]","mtarg1[-163.32,-218.24]","mtarg1[-127.03,-218.24]","mtarg1[-90.73,-218.24]","mtarg1[-54.44,-218.24]","mtarg1[-90.73,-187.06]","mtarg1[-127.03,-187.06]","mtarg1[-127.02,-155.88]","mtarg1[-90.73,-155.88]","mtarg1[-90.73,-124.71]","mtarg1[-127.02,-124.71]","mtarg1[-163.31,-124.71]","mtarg1[-163.31,-93.53]","mtarg1[-127.02,-93.53]","mtarg1[-90.73,-93.53]","mtarg1[-90.73,-62.35]","mtarg1[-127.02,-62.35]","mtarg1[-163.31,-62.35]","mtarg1[-181.45,-31.18]","mtarg1[-145.16,-31.18]","mtarg1[-163.3,0.0]"]
coord0=np.ones_like(a)
coord1=np.ones_like(a)
for i in range(0,124):
    coord0[i]=float(a[i][7:-1].split(",")[0])
    coord1[i]=float(a[i][7:-1].split(",")[1])
    #print i+1 , coord0[i], coord1[i]

# %%
# $targ1="omc2_1b  -r 05:35:33.328439 -d -05:06:15.193627 -e 2000 -v 10"; $ntarg1="3";
# Ra, Dec of targ1
ra_ref = 360*(5.+(35.+33.32839/60.)/60.)/24.
dec_ref= -5.-(6.+15.193627/60.)/60.
print ra_ref, dec_ref
# Out:
# 83.8888682917 -5.10422045194

# %%
# evaluating RA and DEC of each pointing
ra=np.ones_like(coord0)
dec =np.ones_like(coord0)
for i in range(0,124):
    ra[i]=ra_ref+float(coord0[i])/3600.
    dec[i]=dec_ref+float(coord1[i])/3600.
    print i+1 , ra[i], dec[i]
# Out:
# 1 83.8409794028 -5.19515378528
# 2 83.8510599583 -5.19515378528
# 3 83.8611432917 -5.19515378528
# 4 83.8712238472 -5.18649267417
# 5 83.8611432917 -5.18649267417
# 6 83.8359405139 -5.17783156306
# 7 83.856101625 -5.17783156306
# 8 83.8661849583 -5.17783156306
# 9 83.8762655139 -5.16917322972
# 10 83.8661849583 -5.16917322972
# 11 83.8561044028 -5.16917322972
# 12 83.8460210694 -5.16917322972
# 13 83.8460210694 -5.16051211861
# 14 83.8561044028 -5.16051211861
# 15 83.8661849583 -5.16051211861
# 16 83.8762655139 -5.16051211861
# 17 83.8661849583 -5.1518510075
# 18 83.8561044028 -5.1518510075
# 19 83.8460238472 -5.1518510075
# 20 83.8409821806 -5.14319267417
# 21 83.8510627361 -5.14319267417
# 22 83.8611460694 -5.14319267417
# 23 83.871226625 -5.13453156306
# 24 83.8611460694 -5.13453156306
# 25 83.8510655139 -5.13453156306
# 26 83.8409821806 -5.13453156306
# 27 83.8409849583 -5.12587045194
# 28 83.8510655139 -5.12587045194
# 29 83.8611460694 -5.12587045194
# ...

# %% [markdown]
# Polt these pointings, and the mosaic fields are we want to observe covering the mid region of OMC2.

# %%
f_mosaic = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic.show_grayscale()
f_mosaic.add_colorbar()
f_mosaic.colorbar.show()
f_mosaic.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic.colorbar.set_location('top')
f_mosaic.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic.colorbar.set_width(0.15)
f_mosaic.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra.shape[0]):
    f_mosaic.show_circles(float(ra[i]), float(dec[i]), 0.005,linewidths='0.5')

    
f_mosaic.tick_labels.set_font(size='xx-small')
f_mosaic.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Following the sequence of pointings in track1, after doing calibration everytime we will cover the whole region once for visiting every location within our mosaic area approximately every 15~20 mins.

# %%
# loop part one in track1
loop_one=["mtarg1[-172.4,-327.36]","mtarg1[-136.11,-327.36]","mtarg1[-99.81,-327.36]","mtarg1[-63.52,-296.18]","mtarg1[-99.81,-296.18]","mtarg1[-190.54,-265.0]","mtarg1[-117.96,-265.0]","mtarg1[-81.66,-265.0]","mtarg1[-45.37,-233.83]","mtarg1[-81.66,-233.83]","mtarg1[-117.95,-233.83]","mtarg1[-154.25,-233.83]","mtarg1[-154.25,-202.65]","mtarg1[-117.95,-202.65]","mtarg1[-81.66,-202.65]","mtarg1[-45.37,-202.65]","mtarg1[-81.66,-171.47]","mtarg1[-117.95,-171.47]","mtarg1[-154.24,-171.47]","mtarg1[-172.39,-140.3]","mtarg1[-136.1,-140.3]","mtarg1[-99.8,-140.3]","mtarg1[-63.51,-109.12]","mtarg1[-99.8,-109.12]","mtarg1[-136.09,-109.12]","mtarg1[-172.39,-109.12]","mtarg1[-172.38,-77.94]","mtarg1[-136.09,-77.94]","mtarg1[-99.8,-77.94]","mtarg1[-81.65,-46.77]","mtarg1[-117.94,-46.77]","mtarg1[-154.24,-46.77]","mtarg1[-172.38,-15.59]","mtarg1[-172.38,15.59]"]
coord0_loopone=np.ones_like(loop_one)
coord1_loopone=np.ones_like(loop_one)
for i in range(0,33):
    coord0_loopone[i]=float(loop_one[i][7:-1].split(",")[0])
    coord1_loopone[i]=float(loop_one[i][7:-1].split(",")[1])

ra_loopone=np.ones_like(coord0_loopone)
dec_loopone =np.ones_like(coord0_loopone)
for i in range(0,33):
    ra_loopone[i]=ra_ref+float(coord0_loopone[i])/3600.
    dec_loopone[i]=dec_ref+float(coord1_loopone[i])/3600.
    #print i+1 , ra_loopone[i], dec_loopone[i]

# %%
f_mosaic_l1 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic_l1.show_grayscale()
f_mosaic_l1.add_colorbar()
f_mosaic_l1.colorbar.show()
f_mosaic_l1.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic_l1.colorbar.set_location('top')
f_mosaic_l1.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic_l1.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic_l1.colorbar.set_width(0.15)
f_mosaic_l1.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopone.shape[0]):
    f_mosaic_l1.show_circles(float(ra_loopone[i]), float(dec_loopone[i]), 0.005,linewidths='0.5')

    
f_mosaic_l1.tick_labels.set_font(size='xx-small')
f_mosaic_l1.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
#loop part two in track1
loop_two=["mtarg1[-163.33,-311.77]","mtarg1[-127.03,-311.77]","mtarg1[-90.74,-311.77]","mtarg1[-54.44,-280.59]","mtarg1[-90.74,-280.59]","mtarg1[-163.32,-249.42]","mtarg1[-127.03,-249.42]","mtarg1[-90.73,-249.42]","mtarg1[-54.44,-249.42]","mtarg1[-36.29,-218.24]","mtarg1[-72.59,-218.24]","mtarg1[-108.88,-218.24]","mtarg1[-145.17,-218.24]","mtarg1[-145.17,-187.06]","mtarg1[-108.88,-187.06]","mtarg1[-72.59,-187.06]","mtarg1[-72.58,-155.88]","mtarg1[-108.88,-155.88]","mtarg1[-145.17,-155.88]","mtarg1[-181.46,-124.71]","mtarg1[-145.17,-124.71]","mtarg1[-108.88,-124.71]","mtarg1[-72.58,-124.71]","mtarg1[-72.58,-93.53]","mtarg1[-108.87,-93.53]","mtarg1[-145.17,-93.53]","mtarg1[-181.46,-93.53]","mtarg1[-181.45,-62.35]","mtarg1[-145.16,-62.35]","mtarg1[-108.87,-62.35]","mtarg1[-72.58,-62.35]","mtarg1[-127.02,-31.18]","mtarg1[-163.31,-31.18]","mtarg1[-181.45,0.0]"]
coord0_looptwo=np.ones_like(loop_two)
coord1_looptwo=np.ones_like(loop_two)
for i in range(0,33):
    coord0_looptwo[i]=float(loop_two[i][7:-1].split(",")[0])
    coord1_looptwo[i]=float(loop_two[i][7:-1].split(",")[1])

ra_looptwo=np.ones_like(coord0_looptwo)
dec_looptwo =np.ones_like(coord0_looptwo)
for i in range(0,33):
    ra_looptwo[i]=ra_ref+float(coord0_looptwo[i])/3600.
    dec_looptwo[i]=dec_ref+float(coord1_looptwo[i])/3600.
    #print i+1 , ra_loopone[i], dec_loopone[i]

# %%
f_mosaic_l2 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic_l2.show_grayscale()
f_mosaic_l2.add_colorbar()
f_mosaic_l2.colorbar.show()
f_mosaic_l2.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic_l2.colorbar.set_location('top')
f_mosaic_l2.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic_l2.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic_l2.colorbar.set_width(0.15)
f_mosaic_l2.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_looptwo.shape[0]):
    f_mosaic_l2.show_circles(float(ra_looptwo[i]), float(dec_looptwo[i]), 0.005,linewidths='0.5')

    
f_mosaic_l2.tick_labels.set_font(size='xx-small')
f_mosaic_l2.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
#loop part three in track1
loop_three=["mtarg1[-154.25,-327.36]","mtarg1[-117.96,-327.36]","mtarg1[-81.66,-327.36]","mtarg1[-81.66,-296.18]","mtarg1[-99.81,-265.0]","mtarg1[-63.51,-265.0]","mtarg1[-63.51,-233.83]","mtarg1[-99.81,-233.83]","mtarg1[-136.1,-233.83]","mtarg1[-172.39,-233.83]","mtarg1[-136.1,-202.65]","mtarg1[-99.81,-202.65]","mtarg1[-63.51,-202.65]","mtarg1[-99.8,-171.47]","mtarg1[-136.1,-171.47]","mtarg1[-154.24,-140.3]","mtarg1[-117.95,-140.3]","mtarg1[-81.66,-140.3]","mtarg1[-81.66,-109.12]","mtarg1[-117.95,-109.12]","mtarg1[-154.24,-109.12]","mtarg1[-154.24,-77.94]","mtarg1[-117.95,-77.94]","mtarg1[-81.66,-77.94]","mtarg1[-136.09,-46.77]","mtarg1[-172.38,-46.77]","mtarg1[-154.23,-15.59]","mtarg1[-190.52,15.59]"]
coord0_loopthree=np.ones_like(loop_three)
coord1_loopthree=np.ones_like(loop_three)
for i in range(0,27):
    coord0_loopthree[i]=float(loop_three[i][7:-1].split(",")[0])
    coord1_loopthree[i]=float(loop_three[i][7:-1].split(",")[1])

ra_loopthree=np.ones_like(coord0_loopthree)
dec_loopthree =np.ones_like(coord0_loopthree)
for i in range(0,27):
    ra_loopthree[i]=ra_ref+float(coord0_loopthree[i])/3600.
    dec_loopthree[i]=dec_ref+float(coord1_loopthree[i])/3600.

# %%
f_mosaic_l3 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic_l3.show_grayscale()
f_mosaic_l3.add_colorbar()
f_mosaic_l3.colorbar.show()
f_mosaic_l3.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic_l3.colorbar.set_location('top')
f_mosaic_l3.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic_l3.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic_l3.colorbar.set_width(0.15)
f_mosaic_l3.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopthree.shape[0]):
    f_mosaic_l3.show_circles(float(ra_loopthree[i]), float(dec_loopthree[i]), 0.005,linewidths='0.5')

    
f_mosaic_l3.tick_labels.set_font(size='xx-small')
f_mosaic_l3.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
# loop part four in track1
loop_four=["mtarg1[-145.18,-311.77]","mtarg1[-108.88,-311.77]","mtarg1[-72.59,-311.77]","mtarg1[-108.88,-280.59]","mtarg1[-72.59,-280.59]","mtarg1[-72.59,-249.42]","mtarg1[-108.88,-249.42]","mtarg1[-181.47,-249.42]","mtarg1[-163.32,-218.24]","mtarg1[-127.03,-218.24]","mtarg1[-90.73,-218.24]","mtarg1[-54.44,-218.24]","mtarg1[-90.73,-187.06]","mtarg1[-127.03,-187.06]","mtarg1[-127.02,-155.88]","mtarg1[-90.73,-155.88]","mtarg1[-90.73,-124.71]","mtarg1[-127.02,-124.71]","mtarg1[-163.31,-124.71]","mtarg1[-163.31,-93.53]","mtarg1[-127.02,-93.53]","mtarg1[-90.73,-93.53]","mtarg1[-90.73,-62.35]","mtarg1[-127.02,-62.35]","mtarg1[-163.31,-62.35]","mtarg1[-181.45,-31.18]","mtarg1[-145.16,-31.18]","mtarg1[-163.3,0.0]"]
coord0_loopfour=np.ones_like(loop_four)
coord1_loopfour=np.ones_like(loop_four)
for i in range(0,27):
    coord0_loopfour[i]=float(loop_four[i][7:-1].split(",")[0])
    coord1_loopfour[i]=float(loop_four[i][7:-1].split(",")[1])

ra_loopfour=np.ones_like(coord0_loopfour)
dec_loopfour =np.ones_like(coord0_loopfour)
for i in range(0,27):
    ra_loopfour[i]=ra_ref+float(coord0_loopfour[i])/3600.
    dec_loopfour[i]=dec_ref+float(coord1_loopfour[i])/3600.

# %%
f_mosaic_l4 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic_l4.show_grayscale()
f_mosaic_l4.add_colorbar()
f_mosaic_l4.colorbar.show()
f_mosaic_l4.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic_l4.colorbar.set_location('top')
f_mosaic_l4.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic_l4.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic_l4.colorbar.set_width(0.15)
f_mosaic_l4.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopfour.shape[0]):
    f_mosaic_l4.show_circles(float(ra_loopfour[i]), float(dec_loopfour[i]), 0.005,linewidths='0.5')

    
f_mosaic_l4.tick_labels.set_font(size='xx-small')
f_mosaic_l4.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

#
[-208.66,77.94]","mtarg1[-244.95,77.94]","mtarg1[-244.95,109.12]","mtarg1[-208.66,109.12]","mtarg1[-117.96,-358.53]","mtarg1[-154.26,-358.53]","mtarg1[-245.0,-358.53]","mtarg1[-172.41,-389.71]","mtarg1[-136.11,-389.71]","mtarg1[-99.81,-389.71]","mtarg1[-154.26,-420.89]","mtarg1[-190.56,-420.89]","mtarg1[-226.85,-420.89]","mtarg1[-108.87,0.0]","mtarg1[-72.58,0.0]","mtarg1[-36.29,0.0]","mtarg1[0,0]","mtarg1[-18.14,31.18]","mtarg1[-108.87,31.18]","mtarg1[-145.16,31.18]","mtarg1[-199.59,62.35]","mtarg1[-163.3,62.35]","mtarg1[-127.01,62.35]","mtarg1[-90.72,62.35]","mtarg1[-181.44,93.53]","mtarg1[-217.73,93.53]","mtarg1[-254.02,93.53]"]
coord0_sec=np.ones_like(b)
coord1_sec=np.ones_like(b)
for i in range(0,119):
    coord0_sec[i]=float(b[i][7:-1].split(",")[0])
    coord1_sec[i]=float(b[i][7:-1].split(",")[1])
    #print i+1 , coord0_sec[i], coord1_sec[i]

# %%
ra_sec=np.ones_like(coord0_sec)
dec_sec =np.ones_like(coord0_sec)
for i in range(0,119):
    ra_sec[i]=ra_ref+float(coord0_sec[i])/3600.
    dec_sec[i]=dec_ref+float(coord1_sec[i])/3600.
    print i+1 , ra_sec[i], dec_sec[i]
# Out:
# 1 83.8737460694 -5.19948434083
# 2 83.8636627361 -5.19948434083
# 3 83.8535821806 -5.19948434083
# 4 83.8434988472 -5.19948434083
# 5 83.8233349583 -5.19948434083
# 6 83.8182932917 -5.20814267417
# 7 83.8384571806 -5.20814267417
# 8 83.8485405139 -5.20814267417
# 9 83.8586210694 -5.20814267417
# 10 83.8687044028 -5.20814267417
# 11 83.8586210694 -5.21680378528
# 12 83.8485377361 -5.21680378528
# 13 83.8384571806 -5.21680378528
# 14 83.8283738472 -5.21680378528
# 15 83.8233321806 -5.22546489639
# 16 83.8384571806 -5.22546489639
# 17 83.8485377361 -5.22546489639
# 18 83.8283738472 -5.23412322972
# 19 83.8611460694 -5.1085510075
# 20 83.8863488472 -5.1085510075
# 21 83.8863488472 -5.09988989639
# 22 83.8762682917 -5.09988989639
# 23 83.8661877361 -5.09988989639
# 24 83.8561071806 -5.09988989639
# 25 83.8409877361 -5.09122878528
# 26 83.8510682917 -5.09122878528
# 27 83.8611460694 -5.09122878528
# 28 83.8813071806 -5.09122878528
# 29 83.8611488472 -5.08257045194
# ...

# %% [markdown]
# Polt these pointings, and the mosaic fields are we want to observe covering the south and north regions of OMC2.

# %%
f_mosaic_sec = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic_sec.show_grayscale()
f_mosaic_sec.add_colorbar()
f_mosaic_sec.colorbar.show()
f_mosaic_sec.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic_sec.colorbar.set_location('top')
f_mosaic_sec.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic_sec.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic_sec.colorbar.set_width(0.15)
f_mosaic_sec.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_sec.shape[0]):
    f_mosaic_sec.show_circles(float(ra_sec[i]), float(dec_sec[i]), 0.005,linewidths='0.5')

    
f_mosaic_sec.tick_labels.set_font(size='xx-small')
f_mosaic_sec.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Following the sequence of pointings in track2, after doing calibration everytime we will cover the whole region once for visiting every location within our mosaic area approximately every 15~20 mins.

# %%
#loop part one in track2
loop_one2=["mtarg1[-54.44,-342.95]","mtarg1[-90.74,-342.95]","mtarg1[-127.03,-342.95]","mtarg1[-163.33,-342.95]","mtarg1[-235.92,-342.95]","mtarg1[-254.07,-374.12]","mtarg1[-181.48,-374.12]","mtarg1[-145.18,-374.12]","mtarg1[-108.89,-374.12]","mtarg1[-72.59,-374.12]","mtarg1[-108.89,-405.3]","mtarg1[-145.19,-405.3]","mtarg1[-181.48,-405.3]","mtarg1[-217.78,-405.3]","mtarg1[-235.93,-436.48]","mtarg1[-181.48,-436.48]","mtarg1[-145.19,-436.48]","mtarg1[-217.78,-467.65]","mtarg1[-99.8,-15.59]","mtarg1[-9.07,-15.59]","mtarg1[-9.07,15.59]","mtarg1[-45.36,15.59]","mtarg1[-81.65,15.59]","mtarg1[-117.94,15.59]","mtarg1[-172.37,46.77]","mtarg1[-136.08,46.77]","mtarg1[-99.8,46.77]","mtarg1[-27.22,46.77]","mtarg1[-99.79,77.94]","mtarg1[-190.52,77.94]","mtarg1[-226.8,77.94]","mtarg1[-226.8,109.12]","mtarg1[-190.51,109.12]"]
coord0_loopone2=np.ones_like(loop_one2)
coord1_loopone2=np.ones_like(loop_one2)
for i in range(0,33):
    coord0_loopone2[i]=float(loop_one2[i][7:-1].split(",")[0])
    coord1_loopone2[i]=float(loop_one2[i][7:-1].split(",")[1])

ra_loopone2=np.ones_like(coord0_loopone2)
dec_loopone2 =np.ones_like(coord0_loopone2)
for i in range(0,33):
    ra_loopone2[i]=ra_ref+float(coord0_loopone2[i])/3600.
    dec_loopone2[i]=dec_ref+float(coord1_loopone2[i])/3600.

# %%
f_mosaic2_l1 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic2_l1.show_grayscale()
f_mosaic2_l1.add_colorbar()
f_mosaic2_l1.colorbar.show()
f_mosaic2_l1.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic2_l1.colorbar.set_location('top')
f_mosaic2_l1.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic2_l1.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic2_l1.colorbar.set_width(0.15)
f_mosaic2_l1.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopone2.shape[0]):
    f_mosaic2_l1.show_circles(float(ra_loopone2[i]), float(dec_loopone2[i]), 0.005,linewidths='0.5')

    
f_mosaic2_l1.tick_labels.set_font(size='xx-small')
f_mosaic2_l1.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
#loop part two in track2
loop_two2=["mtarg1[-63.52,-358.53]","mtarg1[-99.81,-358.53]","mtarg1[-136.11,-358.53]","mtarg1[-172.4,-358.53]","mtarg1[-226.85,-358.53]","mtarg1[-263.14,-358.53]","mtarg1[-226.85,-389.71]","mtarg1[-190.55,-389.71]","mtarg1[-154.26,-389.71]","mtarg1[-117.96,-389.71]","mtarg1[-136.11,-420.89]","mtarg1[-172.41,-420.89]","mtarg1[-208.71,-420.89]","mtarg1[-245.0,-420.89]","mtarg1[-226.86,-452.07]","mtarg1[-127.01,0.0]","mtarg1[-90.72,0.0]","mtarg1[-54.43,0.0]","mtarg1[-18.14,0.0]","mtarg1[0.0,31.18]","mtarg1[-36.29,31.18]","mtarg1[-90.72,31.18]","mtarg1[-127.01,31.18]","mtarg1[-217.73,62.35]","mtarg1[-181.44,62.35]","mtarg1[-145.16,62.35]","mtarg1[-108.87,62.35]","mtarg1[-72.58,62.35]","mtarg1[-90.72,93.53]","mtarg1[-199.59,93.53]","mtarg1[-235.88,93.53]","mtarg1[-217.73,124.71]"]
coord0_looptwo2=np.ones_like(loop_two2)
coord1_looptwo2=np.ones_like(loop_two2)
for i in range(0,32):
    coord0_looptwo2[i]=float(loop_two2[i][7:-1].split(",")[0])
    coord1_looptwo2[i]=float(loop_two2[i][7:-1].split(",")[1])
    #print i+1 , coord0_looptwo[i], coord1_looptwo[i]
    
ra_looptwo2=np.ones_like(coord0_looptwo2)
dec_looptwo2 =np.ones_like(coord0_looptwo2)
for i in range(0,32):
    ra_looptwo2[i]=ra_ref+float(coord0_looptwo2[i])/3600.
    dec_looptwo2[i]=dec_ref+float(coord1_looptwo2[i])/3600.
    #print i+1 , ra_looptwo2[i], dec_looptwo2[i]

# %%
f_mosaic2_l2 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic2_l2.show_grayscale()
f_mosaic2_l2.add_colorbar()
f_mosaic2_l2.colorbar.show()
f_mosaic2_l2.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic2_l2.colorbar.set_location('top')
f_mosaic2_l2.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic2_l2.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic2_l2.colorbar.set_width(0.15)
f_mosaic2_l2.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_looptwo2.shape[0]):
    f_mosaic2_l2.show_circles(float(ra_looptwo2[i]), float(dec_looptwo2[i]), 0.005,linewidths='0.5')

    
f_mosaic2_l2.tick_labels.set_font(size='xx-small')
f_mosaic2_l2.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
#loop part three in track2
loop_three2=["mtarg1[-72.59,-342.95]","mtarg1[-108.89,-342.95]","mtarg1[-145.18,-342.95]","mtarg1[-181.48,-342.95]","mtarg1[-254.07,-342.95]","mtarg1[-163.33,-374.12]","mtarg1[-127.04,-374.12]","mtarg1[-90.74,-374.12]","mtarg1[-127.04,-405.3]","mtarg1[-163.33,-405.3]","mtarg1[-199.63,-405.3]","mtarg1[-235.93,-405.3]","mtarg1[-163.34,-436.48]","mtarg1[-235.93,-467.65]","mtarg1[-27.22,-15.59]","mtarg1[-27.22,15.59]","mtarg1[-63.51,15.59]","mtarg1[-99.8,15.59]","mtarg1[-136.09,15.59]","mtarg1[-190.52,46.77]","mtarg1[-154.23,46.77]","mtarg1[-117.94,46.77]","mtarg1[-81.65,46.77]","mtarg1[-9.07,46.77]","mtarg1[-81.65,77.94]","mtarg1[-117.94,77.94]","mtarg1[-172.37,77.94]","mtarg1[-208.66,77.94]","mtarg1[-244.95,77.94]","mtarg1[-244.95,109.12]","mtarg1[-208.66,109.12]"]
coord0_loopthree2=np.ones_like(loop_three2)
coord1_loopthree2=np.ones_like(loop_three2)
for i in range(0,31):
    coord0_loopthree2[i]=float(loop_three2[i][7:-1].split(",")[0])
    coord1_loopthree2[i]=float(loop_three2[i][7:-1].split(",")[1])
    
    
ra_loopthree2=np.ones_like(coord0_loopthree2)
dec_loopthree2 =np.ones_like(coord0_loopthree2)
for i in range(0,31):
    ra_loopthree2[i]=ra_ref+float(coord0_loopthree2[i])/3600.
    dec_loopthree2[i]=dec_ref+float(coord1_loopthree2[i])/3600.

# %%
f_mosaic2_l3 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic2_l3.show_grayscale()
f_mosaic2_l3.add_colorbar()
f_mosaic2_l3.colorbar.show()
f_mosaic2_l3.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic2_l3.colorbar.set_location('top')
f_mosaic2_l3.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic2_l3.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic2_l3.colorbar.set_width(0.15)
f_mosaic2_l3.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopthree2.shape[0]):
    f_mosaic2_l3.show_circles(float(ra_loopthree2[i]), float(dec_loopthree2[i]), 0.005,linewidths='0.5')

    
f_mosaic2_l3.tick_labels.set_font(size='xx-small')
f_mosaic2_l3.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %%
# loop part four in track2
loop_four2=["mtarg1[-81.67,-358.53]","mtarg1[-117.96,-358.53]","mtarg1[-154.26,-358.53]","mtarg1[-245.0,-358.53]","mtarg1[-172.41,-389.71]","mtarg1[-136.11,-389.71]","mtarg1[-99.81,-389.71]","mtarg1[-154.26,-420.89]","mtarg1[-190.56,-420.89]","mtarg1[-226.85,-420.89]","mtarg1[-108.87,0.0]","mtarg1[-72.58,0.0]","mtarg1[-36.29,0.0]","mtarg1[0,0]","mtarg1[-18.14,31.18]","mtarg1[-108.87,31.18]","mtarg1[-145.16,31.18]","mtarg1[-199.59,62.35]","mtarg1[-163.3,62.35]","mtarg1[-127.01,62.35]","mtarg1[-90.72,62.35]","mtarg1[-181.44,93.53]","mtarg1[-217.73,93.53]","mtarg1[-254.02,93.53]"]
coord0_loopfour2=np.ones_like(loop_four2)
coord1_loopfour2=np.ones_like(loop_four2)
for i in range(0,24):
    coord0_loopfour2[i]=float(loop_four2[i][7:-1].split(",")[0])
    coord1_loopfour2[i]=float(loop_four2[i][7:-1].split(",")[1])
    #print i+1 , coord0_looptwo[i], coord1_looptwo[i]
    
ra_loopfour2=np.ones_like(coord0_loopfour2)
dec_loopfour2 =np.ones_like(coord0_loopfour2)
for i in range(0,24):
    ra_loopfour2[i]=ra_ref+float(coord0_loopfour2[i])/3600.
    dec_loopfour2[i]=dec_ref+float(coord1_loopfour2[i])/3600.

# %%
f_mosaic2_l4 = aplpy.FITSFigure('/nfshome/sihanjiao/Desktop/sma_checking/orion_sma.fits', figsize=(7,7))
f_mosaic2_l4.show_grayscale()
f_mosaic2_l4.add_colorbar()
f_mosaic2_l4.colorbar.show()
f_mosaic2_l4.recenter(83.855,-5.14969,width=0.133,height=0.177)
f_mosaic2_l4.colorbar.set_location('top')
f_mosaic2_l4.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f_mosaic2_l4.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f_mosaic2_l4.colorbar.set_width(0.15)
f_mosaic2_l4.colorbar.set_ticks([0.05,0.1,0.2])


for i in range(0,ra_loopfour2.shape[0]):
    f_mosaic2_l4.show_circles(float(ra_loopfour2[i]), float(dec_loopfour2[i]), 0.005,linewidths='0.5')

    
f_mosaic2_l4.tick_labels.set_font(size='xx-small')
f_mosaic2_l4.axis_labels.set_font(size='x-small')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]
