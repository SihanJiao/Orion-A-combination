# %%
import matplotlib
from astropy import units as u
import aplpy
import numpy as np
import astropy.io.fits as fits
from astropy.io import ascii
from astropy.table import Column, Table
# %matplotlib inline
# Out:
# /Users/shjiao/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# The observing scripts are written following Baobab's example
# https://github.com/baobabyoo/OMC_SMAmegaMosaic_2017Nov/blob/master/sma_omc_loop.ipynb

# %% [markdown]
# # OMC3

# %% [markdown]
# Defining loop

# %%
oldstyle_loop1 = 'cal0,cal1,targ1,targ2,targ3,targ4,targ5,targ6,targ7,targ8,targ9,targ10,targ11,targ12,targ13,targ14,targ15,targ16,targ17,targ18,targ19,targ20,targ21,targ22,targ23,targ24,targ25,targ26,targ27,targ28,targ29,targ30,targ31,targ32,cal0,cal1,targ33,targ34,targ35,targ36,targ37,targ38,targ39,targ40,targ41,targ42,targ43,targ44,targ45,targ46,targ47,targ48,targ49,targ50,targ51,targ52,targ53,targ54,targ55,targ56,targ57,targ58,targ59,targ60,targ61,targ62,targ63,targ64,targ65,cal0,cal1,targ66,targ67,targ68,targ69,targ70,targ71,targ72,targ73,targ74,targ75,targ76,targ77,targ78,targ79,targ80,targ81,targ82,targ83,targ84,targ85,targ86,targ87,targ88,targ89,targ90,targ91,targ92,targ93,targ94,targ95,targ96,cal0,cal1,targ97,targ98,targ99,targ100,targ101,targ102,targ103,targ104,targ105,targ106,targ107,targ108,targ109,targ110,targ111,targ112,targ113,targ114,targ115,targ116,targ117,targ118,targ119,targ120,targ121,targ122,targ123,targ124,targ125,targ126'

print ( "First target is: targ1; Last is targ126\n")
print ( oldstyle_loop1, '\n' )

# splitting elements in loops as independent string variables
oldstyle_loop1_list = oldstyle_loop1.split(',')


print ( 'Loop 1 list \n' )
print ( oldstyle_loop1_list )
# Out:
# First target is: targ1; Last is targ126
#
# ('cal0,cal1,targ1,targ2,targ3,targ4,targ5,targ6,targ7,targ8,targ9,targ10,targ11,targ12,targ13,targ14,targ15,targ16,targ17,targ18,targ19,targ20,targ21,targ22,targ23,targ24,targ25,targ26,targ27,targ28,targ29,targ30,targ31,targ32,cal0,cal1,targ33,targ34,targ35,targ36,targ37,targ38,targ39,targ40,targ41,targ42,targ43,targ44,targ45,targ46,targ47,targ48,targ49,targ50,targ51,targ52,targ53,targ54,targ55,targ56,targ57,targ58,targ59,targ60,targ61,targ62,targ63,targ64,targ65,cal0,cal1,targ66,targ67,targ68,targ69,targ70,targ71,targ72,targ73,targ74,targ75,targ76,targ77,targ78,targ79,targ80,targ81,targ82,targ83,targ84,targ85,targ86,targ87,targ88,targ89,targ90,targ91,targ92,targ93,targ94,targ95,targ96,cal0,cal1,targ97,targ98,targ99,targ100,targ101,targ102,targ103,targ104,targ105,targ106,targ107,targ108,targ109,targ110,targ111,targ112,targ113,targ114,targ115,targ116,targ117,targ118,targ119,targ120,targ121,targ122,targ123,targ124,targ125,targ126', '\n')
# ...

# %% [markdown]
# Loading the coordinate table

# %%
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for pnt_id in range( len(dec) ):
    print pnt_id + 1, ra[pnt_id], dec[pnt_id]
# Out:
# 1 83.8649794028 -5.06916490306
# 2 83.8549794028 -5.06916490306
# 3 83.8649794028 -5.06049824306
# 4 83.8549794028 -5.06049824306
# 5 83.8549794028 -5.05183158306
# 6 83.8649794028 -5.05183158306
# 7 83.8549794028 -5.04316492306
# 8 83.8449794028 -5.03449826306
# 9 83.8549794028 -5.03449826306
# 10 83.8549794028 -5.02583160306
# 11 83.8449794028 -5.02583160306
# 12 83.8349794028 -5.02583160306
# 13 83.8249794028 -5.02583160306
# 14 83.8249794028 -5.01716494306
# 15 83.8349794028 -5.01716494306
# 16 83.8449794028 -5.01716494306
# 17 83.8549794028 -5.01716494306
# 18 83.8349794028 -5.00849828306
# 19 83.8249794028 -5.00849828306
# 20 83.8149794028 -5.00849828306
# 21 83.7949794028 -4.99983162306
# 22 83.8049794028 -4.99983162306
# 23 83.8149794028 -4.99983162306
# 24 83.8249794028 -4.99983162306
# 25 83.8349794028 -4.99983162306
# 26 83.8149794028 -4.99116496306
# 27 83.8049794028 -4.99116496306
# 28 83.7949794028 -4.98249830306
# 29 83.8049794028 -4.98249830306
# ...

# %%
ra  = ( rah + ram / 60.0 + ras / 3600.0 ) * 15.0
dec = np.arange( len(ra) ) * 0.0

# %%
(4.149894183599994-4)*60
# Out:
# 8.993651015999617

# %% [markdown]
# Evaluating pointing offsets

# %%
raoffset_arcsec  =  np.arange( len(ra) ) * 0.0
decoffset_arcsec =  np.arange( len(ra) ) * 0.0

for pnt_id in range( len(dec) ):
    raoffset_arcsec[pnt_id]  = ( ra[pnt_id]  - ra[0] )  * 3600.0 \
                               / math.cos( dec[pnt_id] * (np.pi / 180.0) )
    decoffset_arcsec[pnt_id] = ( dec[pnt_id] - dec[0] ) * 3600.0
    

    
for pnt_id in range( len(dec) ):
    print pnt_id + 1, raoffset_arcsec[pnt_id],  decoffset_arcsec[pnt_id]
# Out:
# 1 0.0 0.0
# 2 -36.1413574593 0.0
# 3 0.0 31.199976
# 4 -36.1408729453 31.199976
# 5 -36.1403892711 62.399952
# 6 0.0 62.399952
# 7 -36.1399064368 93.599928
# 8 -72.2788488845 124.799904
# 9 -36.1394244423 124.799904
# 10 -36.1389432874 155.99988
# 11 -72.2778865748 155.99988
# 12 -108.416829862 155.99988
# 13 -144.55577315 155.99988
# 14 -144.553851889 187.199856
# 15 -108.415388917 187.199856
# 16 -72.2769259444 187.199856
# 17 -36.1384629722 187.199856
# 18 -108.41395049 218.399832
# 19 -144.551933986 218.399832
# 20 -180.689917483 218.399832
# 21 -252.962534024 249.599808
# 22 -216.825029163 249.599808
# 23 -180.687524303 249.599808
# 24 -144.550019442 249.599808
# 25 -108.412514582 249.599808
# 26 -180.68513532 280.799784
# 27 -216.822162384 280.799784
# 28 -252.955850748 311.99976
# 29 -216.819300641 311.99976
# 30 -216.816443935 343.199736
# 31 -252.952517924 343.199736
# 32 -252.949190975 374.399712
# 33 -18.0706787297 0.0
# 34 18.0704364726 31.199976
# ...

# %% [markdown]
# Constructing Looping command

# %%
# Constructing a dictionary between scan name and scan coordinate offset
offsetdict = {}
offsetdict['cal0'] = 'cal0'
offsetdict['cal1'] = 'cal1'
offsetdict['targ1'] = 'targ1'

for pnt_id in range(2, len(dec)+1 ):
    scan_name = 'targ' + str(pnt_id)
    offsetdict[scan_name] = '"m' + offsetdict['targ1'] \
                          + '[' + str( round(raoffset_arcsec[pnt_id  -1],2) ) + ','  \
                          +       str( round(decoffset_arcsec[pnt_id -1],2) ) + ']"'

loop1 = "&ObsLoop("
for scan_id in range( len(oldstyle_loop1_list) ): 
    print oldstyle_loop1_list[scan_id], ' -> ', offsetdict[ oldstyle_loop1_list[scan_id] ] 
    loop1 = loop1 + offsetdict[ oldstyle_loop1_list[scan_id] ]
    if ( scan_id != (len(oldstyle_loop1_list) -1) ):
        loop1 = loop1 + ','
    else:
        loop1 = loop1 + ');'
# Out:
# cal0  ->  cal0
# cal1  ->  cal1
# targ1  ->  targ1
# targ2  ->  "mtarg1[-36.14,0.0]"
# targ3  ->  "mtarg1[0.0,31.2]"
# targ4  ->  "mtarg1[-36.14,31.2]"
# targ5  ->  "mtarg1[-36.14,62.4]"
# targ6  ->  "mtarg1[0.0,62.4]"
# targ7  ->  "mtarg1[-36.14,93.6]"
# targ8  ->  "mtarg1[-72.28,124.8]"
# targ9  ->  "mtarg1[-36.14,124.8]"
# targ10  ->  "mtarg1[-36.14,156.0]"
# targ11  ->  "mtarg1[-72.28,156.0]"
# targ12  ->  "mtarg1[-108.42,156.0]"
# targ13  ->  "mtarg1[-144.56,156.0]"
# targ14  ->  "mtarg1[-144.55,187.2]"
# targ15  ->  "mtarg1[-108.42,187.2]"
# targ16  ->  "mtarg1[-72.28,187.2]"
# targ17  ->  "mtarg1[-36.14,187.2]"
# targ18  ->  "mtarg1[-108.41,218.4]"
# targ19  ->  "mtarg1[-144.55,218.4]"
# targ20  ->  "mtarg1[-180.69,218.4]"
# targ21  ->  "mtarg1[-252.96,249.6]"
# targ22  ->  "mtarg1[-216.83,249.6]"
# targ23  ->  "mtarg1[-180.69,249.6]"
# targ24  ->  "mtarg1[-144.55,249.6]"
# targ25  ->  "mtarg1[-108.41,249.6]"
# targ26  ->  "mtarg1[-180.69,280.8]"
# ...

# %% [markdown]
# Printing loop commands:

# %%
print  "New format Loop1 \n" 
print  loop1, '\n'
# Out:
# New format Loop1
#
# ...

# %% [markdown]
# Actual scripts for OMC3

# %%
# compact track for OMC3

#!/usr/bin/perl -w
{ BEGIN {$^W =0}
#
################## Script Header Info #####################
#
# Experiment Code: 2018A-S028
# Experiment Title: Continuation of SMA Public Survey towards the Orion Molecular Cloud
# PI: Sihan Jiao
# Contact Person: Sihan Jiao / Baobab Liu
# Email  : sihanjiao@nao.cas.cn / baobabyoo@gmail.com
# Office : +86-18205095977  / +49 017643305521
# Home   : +86-18205095977   
# Array  : compact   
#
#
############## SPECIAL INSTRUCTIONS ################
#
# 1. Mosaic setup.
#    This is a mega mosaic project. 
#    Need help to execute in the way that Tsys is not
#    measured as often as switching field.
#
# 2. Timing
#    It will take approximately one hour to finish the loop.
#    For the mid night pointing, please wait until a loop is completed,
#    instead of breaking a loop to do pointing.
#
################## Priming ################################
#
# observe -s omc3 -r 05:35:20 -d -05:01:00 -e 2000 -v 10
# dopplerTrack -S omc3 -r 346 -u -s1 -f 0.0 -R B -r 344 -l -s1 -f 0.0
#
################## Pointing ###############################
#
# Pointing: At start and in middle of track
# Syntax Example: point -i 60 -r 3 -L -l -t -Q
#
################## Source, Calibrator and Limits ##########
#
$inttime="10"; 
$targ0="omc3 -r 05:35:20 -d -05:01:00 -e 2000 -v 10"; $ntarg0="2"; 

$targ1="omc2_1b  -r 05:35:27.595056672000737 -d -05:04:08.993651015999617 -e 2000 -v 10"; $ntarg1="2";

$cal0="0433+053"; $ncal0="15";
$cal1="0501-019"; $ncal1="15";
$flux0="Uranus"; $nflux0="60";
$flux1="Callisto"; $nflux1="60";
$bpass0="3C84"; $nbpass0="400";
$bpass1="3C279"; $nbpass1="400";
$MINEL_TARG = 17; $MAXEL_TARG = 83;
$MINEL_GAIN = 17; $MAXEL_GAIN = 83;
$MINEL_FLUX = 17; $MAXEL_FLUX = 81;
$MINEL_BPASS= 17; $MAXEL_BPASS= 87;
$MINEL_CHECK= 19; 
#
################## Script Initialization ##################
#
do 'sma.pl';
do 'sma_add.pl';
checkANT();
command("radio");
command("integrate -t $inttime");
$myPID=$$;
command("project -r -p 'Sihan Jiao' -d '2018A-S028'");
print "----- initialization done, starting script -----\n";
#
################## Science Script #########################
#
print "----- initial flux and bandpass calibration -----\n";
if(!$restart){
  &DoPass(bpass0,nbpass0);
  &DoFlux(flux0,nflux0);
}

print "----- main science target observe loop -----\n";
&ObsLoop(cal0,cal1,targ1,"mtarg1[-36.14,0.0]","mtarg1[0.0,31.2]","mtarg1[-36.14,31.2]","mtarg1[-36.14,62.4]","mtarg1[0.0,62.4]","mtarg1[-36.14,93.6]","mtarg1[-72.28,124.8]","mtarg1[-36.14,124.8]","mtarg1[-36.14,156.0]","mtarg1[-72.28,156.0]","mtarg1[-108.42,156.0]","mtarg1[-144.56,156.0]","mtarg1[-144.55,187.2]","mtarg1[-108.42,187.2]","mtarg1[-72.28,187.2]","mtarg1[-36.14,187.2]","mtarg1[-108.41,218.4]","mtarg1[-144.55,218.4]","mtarg1[-180.69,218.4]","mtarg1[-252.96,249.6]","mtarg1[-216.83,249.6]","mtarg1[-180.69,249.6]","mtarg1[-144.55,249.6]","mtarg1[-108.41,249.6]","mtarg1[-180.69,280.8]","mtarg1[-216.82,280.8]","mtarg1[-252.96,312.0]","mtarg1[-216.82,312.0]","mtarg1[-216.82,343.2]","mtarg1[-252.95,343.2]","mtarg1[-252.95,374.4]",cal0,cal1,"mtarg1[-18.07,0.0]","mtarg1[18.07,31.2]","mtarg1[-18.07,31.2]","mtarg1[-54.21,31.2]","mtarg1[-54.21,62.4]","mtarg1[-18.07,62.4]","mtarg1[-54.21,93.6]","mtarg1[-54.21,124.8]","mtarg1[-18.07,156.0]","mtarg1[-54.21,156.0]","mtarg1[-90.35,156.0]","mtarg1[-126.49,156.0]","mtarg1[-162.63,156.0]","mtarg1[-162.62,187.2]","mtarg1[-126.48,187.2]","mtarg1[-90.35,187.2]","mtarg1[-54.21,187.2]","mtarg1[-18.07,187.2]","mtarg1[-90.34,218.4]","mtarg1[-126.48,218.4]","mtarg1[-162.62,218.4]","mtarg1[-198.76,218.4]","mtarg1[-271.03,249.6]","mtarg1[-198.76,249.6]","mtarg1[-162.62,249.6]","mtarg1[-126.48,249.6]","mtarg1[-162.62,280.8]","mtarg1[-198.75,280.8]","mtarg1[-234.89,280.8]","mtarg1[-234.89,312.0]","mtarg1[-198.75,312.0]","mtarg1[-234.88,343.2]","mtarg1[-271.02,374.4]",cal0,cal1,"mtarg1[-45.18,15.6]","mtarg1[-9.04,15.6]","mtarg1[-9.04,46.8]","mtarg1[-45.18,46.8]","mtarg1[-45.18,78.0]","mtarg1[-45.17,109.2]","mtarg1[-153.59,140.4]","mtarg1[-117.45,140.4]","mtarg1[-81.31,140.4]","mtarg1[-45.17,140.4]","mtarg1[-9.03,171.6]","mtarg1[-45.17,171.6]","mtarg1[-81.31,171.6]","mtarg1[-117.45,171.6]","mtarg1[-153.59,171.6]","mtarg1[-153.59,202.8]","mtarg1[-117.45,202.8]","mtarg1[-81.31,202.8]","mtarg1[-117.45,234.0]","mtarg1[-153.59,234.0]","mtarg1[-189.72,234.0]","mtarg1[-262.0,265.2]","mtarg1[-225.86,265.2]","mtarg1[-189.72,265.2]","mtarg1[-153.58,265.2]","mtarg1[-189.72,296.4]","mtarg1[-225.85,296.4]","mtarg1[-261.99,327.6]","mtarg1[-225.85,327.6]","mtarg1[-261.98,358.8]","mtarg1[-261.98,390.0]",cal0,cal1,"mtarg1[-27.11,15.6]","mtarg1[9.04,46.8]","mtarg1[-27.11,46.8]","mtarg1[-63.25,46.8]","mtarg1[-27.11,78.0]","mtarg1[-63.24,109.2]","mtarg1[-135.52,140.4]","mtarg1[-63.24,140.4]","mtarg1[-27.1,140.4]","mtarg1[-27.1,171.6]","mtarg1[-63.24,171.6]","mtarg1[-99.38,171.6]","mtarg1[-135.52,171.6]","mtarg1[-171.66,202.8]","mtarg1[-135.52,202.8]","mtarg1[-99.38,202.8]","mtarg1[-99.38,234.0]","mtarg1[-135.52,234.0]","mtarg1[-171.65,234.0]","mtarg1[-207.79,234.0]","mtarg1[-243.93,234.0]","mtarg1[-207.79,265.2]","mtarg1[-171.65,265.2]","mtarg1[-135.51,265.2]","mtarg1[-207.79,296.4]","mtarg1[-243.92,296.4]","mtarg1[-243.92,327.6]","mtarg1[-207.78,327.6]","mtarg1[-243.92,358.8]","mtarg1[-280.05,390.0]");

print "----- final flux and bandpass calibration -----\n";
  &DoFlux(flux1,nflux1);
  &DoPass(bpass1,nbpass1);

print "----- Congratulations!  This is the end of the script.  -----\n";}
#
################## File End ###############################

# %% [markdown]
# # OMC1_part1

# %%
oldstyle_loop_omc1_part1 = 'cal0,cal1,targ1,targ2,targ3,targ4,targ5,targ6,targ7,targ8,targ9,targ10,targ11,targ12,targ13,targ14,targ15,targ16,targ17,targ18,targ19,targ20,targ21,targ22,targ23,targ24,targ25,targ26,targ27,targ28,targ29,targ30,targ31,targ32,targ33,targ34,targ35,cal0,cal1,targ36,targ37,targ38,targ39,targ40,targ41,targ42,targ43,targ44,targ45,targ46,targ47,targ48,targ49,targ50,targ51,targ52,targ53,targ54,targ55,targ56,targ57,targ58,targ59,targ60,targ61,targ62,targ63,targ64,targ65,targ66,targ67,cal0,cal1,targ68,targ69,targ70,targ71,targ72,targ73,targ74,targ75,targ76,targ77,targ78,targ79,targ80,targ81,targ82,targ83,targ84,targ85,targ86,targ87,targ88,targ89,targ90,targ91,targ92,targ93,targ94,targ95,targ96,targ97,targ98,cal0,cal1,targ99,targ100,targ101,targ102,targ103,targ104,targ105,targ106,targ107,targ108,targ109,targ110,targ111,targ112,targ113,targ114,targ115,targ116,targ117,targ118,targ119,targ120,targ121,targ122,targ123,targ124,targ125,targ126,targ127,targ128'

print  "First target is: targ1; Last is targ128\n"
print  oldstyle_loop_omc1_part1, '\n' 

# splitting elements in loops as independent string variables
oldstyle_loop_omc1_part1_list = oldstyle_loop_omc1_part1.split(',')


print  'Loop 1 list \n' 
print  oldstyle_loop_omc1_part1_list
# Out:
# First target is: targ1; Last is targ128
#
# ...

# %%
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop2.csv'
jps_cat=ascii.read(jps_file)

for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop3.csv'
jps_cat=ascii.read(jps_file)

for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop4.csv'
jps_cat=ascii.read(jps_file)

for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for pnt_id in range( len(dec) ):
    print pnt_id + 1, ra[pnt_id], dec[pnt_id]
# Out:
# 1 83.8111111111 -5.32472045861
# 2 83.8211111111 -5.32472045861
# 3 83.8311111111 -5.32472045861
# 4 83.8411111111 -5.32472045861
# 5 83.8511111111 -5.32472045861
# 6 83.8411111111 -5.31605379861
# 7 83.8311111111 -5.31605379861
# 8 83.8211111111 -5.31605379861
# 9 83.8111111111 -5.31605379861
# 10 83.8111111111 -5.30738713861
# 11 83.8211111111 -5.30738713861
# 12 83.8311111111 -5.30738713861
# 13 83.8411111111 -5.30738713861
# 14 83.8411111111 -5.29872047861
# 15 83.8311111111 -5.29872047861
# 16 83.8211111111 -5.29872047861
# 17 83.8111111111 -5.29872047861
# 18 83.8111111111 -5.29005381861
# 19 83.8311111111 -5.29005381861
# 20 83.8411111111 -5.29005381861
# 21 83.8111111111 -5.28138715861
# 22 83.8111111111 -5.27272049861
# 23 83.8211111111 -5.27272049861
# 24 83.8311111111 -5.26405383861
# 25 83.8211111111 -5.26405383861
# 26 83.8111111111 -5.26405383861
# 27 83.8111111111 -5.25538717861
# 28 83.8211111111 -5.25538717861
# 29 83.8311111111 -5.25538717861
# ...

# %%
((5.32472045861-5)*60-19)*60
# Out:
# 28.993650995999545

# %% [markdown]
# Evaluating pointing offsets

# %%
raoffset_arcsec  =  np.arange( len(ra) ) * 0.0
decoffset_arcsec =  np.arange( len(ra) ) * 0.0

for pnt_id in range( len(dec) ):
    raoffset_arcsec[pnt_id]  = ( ra[pnt_id]  - ra[0] )  * 3600.0 \
                               / math.cos( dec[pnt_id] * (np.pi / 180.0) )
    decoffset_arcsec[pnt_id] = ( dec[pnt_id] - dec[0] ) * 3600.0
    

    
for pnt_id in range( len(dec) ):
    print pnt_id + 1, raoffset_arcsec[pnt_id],  decoffset_arcsec[pnt_id]
# Out:
# 1 0.0 0.0
# 2 36.156022206 0.0
# 3 72.312044412 0.0
# 4 108.468066618 0.0
# 5 144.624088824 0.0
# 6 108.466538702 31.199976
# 7 72.3110258016 31.199976
# 8 36.1555129008 31.199976
# 9 0.0 31.199976
# 10 0.0 62.399952
# 11 36.1550044372 62.399952
# 12 72.3100088744 62.399952
# 13 108.465013312 62.399952
# 14 108.463490445 93.599928
# 15 72.3089936302 93.599928
# 16 36.1544968151 93.599928
# 17 0.0 93.599928
# 18 0.0 124.799904
# 19 72.3079800689 124.799904
# 20 108.461970103 124.799904
# 21 0.0 155.99988
# 22 0.0 187.199856
# 23 36.1529789973 187.199856
# 24 72.3049494812 218.399832
# 25 36.1524747406 218.399832
# 26 0.0 218.399832
# 27 0.0 249.599808
# 28 36.1519713252 249.599808
# 29 72.3039426504 249.599808
# 30 108.455913976 249.599808
# 31 144.607885301 249.599808
# 32 108.454406253 280.799784
# 33 72.3029375018 280.799784
# 34 36.1514687509 280.799784
# 35 108.452901053 311.99976
# 36 -18.078011103 0.0
# 37 18.078011103 0.0
# 38 54.234033309 0.0
# 39 90.390055515 0.0
# ...

# %% [markdown]
# Constructing Looping command

# %%
# Constructing a dictionary between scan name and scan coordinate offset
offsetdict = {}
offsetdict['cal0'] = 'cal0'
offsetdict['cal1'] = 'cal1'
offsetdict['targ1'] = 'targ1'

for pnt_id in range(2, len(dec)+1 ):
    scan_name = 'targ' + str(pnt_id)
    offsetdict[scan_name] = '"m' + offsetdict['targ1'] \
                          + '[' + str( round(raoffset_arcsec[pnt_id  -1],2) ) + ','  \
                          +       str( round(decoffset_arcsec[pnt_id -1],2) ) + ']"'

omc1_part1_loop1 = "&ObsLoop("
for scan_id in range( len(oldstyle_loop_omc1_part1_list) ): 
    print oldstyle_loop_omc1_part1_list[scan_id], ' -> ', offsetdict[ oldstyle_loop_omc1_part1_list[scan_id] ] 
    omc1_part1_loop1 = omc1_part1_loop1 + offsetdict[ oldstyle_loop_omc1_part1_list[scan_id] ]
    if ( scan_id != (len(oldstyle_loop_omc1_part1_list) -1) ):
        omc1_part1_loop1 = omc1_part1_loop1 + ','
    else:
        omc1_part1_loop1 = omc1_part1_loop1 + ');'
# Out:
# cal0  ->  cal0
# cal1  ->  cal1
# targ1  ->  targ1
# targ2  ->  "mtarg1[36.16,0.0]"
# targ3  ->  "mtarg1[72.31,0.0]"
# targ4  ->  "mtarg1[108.47,0.0]"
# targ5  ->  "mtarg1[144.62,0.0]"
# targ6  ->  "mtarg1[108.47,31.2]"
# targ7  ->  "mtarg1[72.31,31.2]"
# targ8  ->  "mtarg1[36.16,31.2]"
# targ9  ->  "mtarg1[0.0,31.2]"
# targ10  ->  "mtarg1[0.0,62.4]"
# targ11  ->  "mtarg1[36.16,62.4]"
# targ12  ->  "mtarg1[72.31,62.4]"
# targ13  ->  "mtarg1[108.47,62.4]"
# targ14  ->  "mtarg1[108.46,93.6]"
# targ15  ->  "mtarg1[72.31,93.6]"
# targ16  ->  "mtarg1[36.15,93.6]"
# targ17  ->  "mtarg1[0.0,93.6]"
# targ18  ->  "mtarg1[0.0,124.8]"
# targ19  ->  "mtarg1[72.31,124.8]"
# targ20  ->  "mtarg1[108.46,124.8]"
# targ21  ->  "mtarg1[0.0,156.0]"
# targ22  ->  "mtarg1[0.0,187.2]"
# targ23  ->  "mtarg1[36.15,187.2]"
# targ24  ->  "mtarg1[72.3,218.4]"
# targ25  ->  "mtarg1[36.15,218.4]"
# targ26  ->  "mtarg1[0.0,218.4]"
# targ27  ->  "mtarg1[0.0,249.6]"
# targ28  ->  "mtarg1[36.15,249.6]"
# ...

# %%
print  "New format omc1_part1_loop1 \n" 
print  omc1_part1_loop1, '\n'
# Out:
# New format omc1_part1_loop1
#
# ...

# %%
# compact track for OMC1_part1

#!/usr/bin/perl -w
{ BEGIN {$^W =0}
#
################## Script Header Info #####################
#
# Experiment Code: 2018A-S028
# Experiment Title: Continuation of SMA Public Survey towards the Orion Molecular Cloud
# PI: Sihan Jiao
# Contact Person: Sihan Jiao / Baobab Liu
# Email  : sihanjiao@nao.cas.cn / baobabyoo@gmail.com
# Office : +86-18205095977  / +49 017643305521
# Home   : +86-18205095977   
# Array  : compact   
#
#
############## SPECIAL INSTRUCTIONS ################
#
# 1. Mosaic setup.
#    This is a mega mosaic project. 
#    Need help to execute in the way that Tsys is not
#    measured as often as switching field.
#
# 2. Timing
#    It will take approximately one hour to finish the loop.
#    For the mid night pointing, please wait until a loop is completed,
#    instead of breaking a loop to do pointing.
#
################## Priming ################################
#
# observe -s omc1 -r 05:35:20 -d -05:01:00 -e 2000 -v 10
# dopplerTrack -S omc1 -r 346 -u -s1 -f 0.0 -R B -r 344 -l -s1 -f 0.0
#
################## Pointing ###############################
#
# Pointing: At start and in middle of track
# Syntax Example: point -i 60 -r 3 -L -l -t -Q
#
################## Source, Calibrator and Limits ##########
#
$inttime="10"; 
$targ0="omc1 -r 05:35:15 -d -05:20:00 -e 2000 -v 10"; $ntarg0="2"; 

$targ1="omc1_targ1  -r 05:35:14.666666664002292 -d -05:19:28.993650995999545 -e 2000 -v 10"; $ntarg1="2";

$cal0="0433+053"; $ncal0="15";
$cal1="0501-019"; $ncal1="15";
$flux0="Uranus"; $nflux0="60";
$flux1="Callisto"; $nflux1="60";
$bpass0="3C84"; $nbpass0="400";
$bpass1="3C279"; $nbpass1="400";
$MINEL_TARG = 17; $MAXEL_TARG = 83;
$MINEL_GAIN = 17; $MAXEL_GAIN = 83;
$MINEL_FLUX = 17; $MAXEL_FLUX = 81;
$MINEL_BPASS= 17; $MAXEL_BPASS= 87;
$MINEL_CHECK= 19; 
#
################## Script Initialization ##################
#
do 'sma.pl';
do 'sma_add.pl';
checkANT();
command("radio");
command("integrate -t $inttime");
$myPID=$$;
command("project -r -p 'Sihan Jiao' -d '2018A-S028'");
print "----- initialization done, starting script -----\n";
#
################## Science Script #########################
#
print "----- initial flux and bandpass calibration -----\n";
if(!$restart){
  &DoPass(bpass0,nbpass0);
  &DoFlux(flux0,nflux0);
}

print "----- main science target observe loop -----\n";
&ObsLoop(cal0,cal1,targ1,"mtarg1[36.16,0.0]","mtarg1[72.31,0.0]","mtarg1[108.47,0.0]","mtarg1[144.62,0.0]","mtarg1[108.47,31.2]","mtarg1[72.31,31.2]","mtarg1[36.16,31.2]","mtarg1[0.0,31.2]","mtarg1[0.0,62.4]","mtarg1[36.16,62.4]","mtarg1[72.31,62.4]","mtarg1[108.47,62.4]","mtarg1[108.46,93.6]","mtarg1[72.31,93.6]","mtarg1[36.15,93.6]","mtarg1[0.0,93.6]","mtarg1[0.0,124.8]","mtarg1[72.31,124.8]","mtarg1[108.46,124.8]","mtarg1[0.0,156.0]","mtarg1[0.0,187.2]","mtarg1[36.15,187.2]","mtarg1[72.3,218.4]","mtarg1[36.15,218.4]","mtarg1[0.0,218.4]","mtarg1[0.0,249.6]","mtarg1[36.15,249.6]","mtarg1[72.3,249.6]","mtarg1[108.46,249.6]","mtarg1[144.61,249.6]","mtarg1[108.45,280.8]","mtarg1[72.3,280.8]","mtarg1[36.15,280.8]","mtarg1[108.45,312.0]",cal0,cal1,"mtarg1[-18.08,0.0]","mtarg1[18.08,0.0]","mtarg1[54.23,0.0]","mtarg1[90.39,0.0]","mtarg1[126.55,0.0]","mtarg1[126.54,31.2]","mtarg1[90.39,31.2]","mtarg1[54.23,31.2]","mtarg1[18.08,31.2]","mtarg1[-18.08,31.2]","mtarg1[-18.08,62.4]","mtarg1[18.08,62.4]","mtarg1[54.23,62.4]","mtarg1[90.39,62.4]","mtarg1[90.39,93.6]","mtarg1[54.23,93.6]","mtarg1[18.08,93.6]","mtarg1[-18.08,93.6]","mtarg1[90.38,124.8]","mtarg1[18.08,156.0]","mtarg1[18.08,187.2]","mtarg1[18.08,218.4]","mtarg1[18.08,249.6]","mtarg1[54.23,249.6]","mtarg1[90.38,249.6]","mtarg1[126.53,249.6]","mtarg1[126.53,280.8]","mtarg1[90.38,280.8]","mtarg1[54.23,280.8]","mtarg1[18.08,280.8]","mtarg1[90.38,312.0]","mtarg1[126.53,312.0]",cal0,cal1,"mtarg1[-9.04,15.6]","mtarg1[27.12,15.6]","mtarg1[63.27,15.6]","mtarg1[99.43,15.6]","mtarg1[135.58,15.6]","mtarg1[99.43,46.8]","mtarg1[63.27,46.8]","mtarg1[27.12,46.8]","mtarg1[-9.04,46.8]","mtarg1[-9.04,78.0]","mtarg1[27.12,78.0]","mtarg1[63.27,78.0]","mtarg1[99.43,78.0]","mtarg1[99.42,109.2]","mtarg1[63.27,109.2]","mtarg1[-9.04,109.2]","mtarg1[-9.04,140.4]","mtarg1[27.11,171.6]","mtarg1[-9.04,171.6]","mtarg1[-9.04,202.8]","mtarg1[27.11,202.8]","mtarg1[135.57,234.0]","mtarg1[99.42,234.0]","mtarg1[63.27,234.0]","mtarg1[27.11,234.0]","mtarg1[-9.04,234.0]","mtarg1[27.11,265.2]","mtarg1[63.27,265.2]","mtarg1[99.42,265.2]","mtarg1[135.57,265.2]","mtarg1[99.42,296.4]",cal0,cal1,"mtarg1[-27.12,15.6]","mtarg1[9.04,15.6]","mtarg1[45.19,15.6]","mtarg1[81.35,15.6]","mtarg1[117.51,15.6]","mtarg1[81.35,46.8]","mtarg1[45.19,46.8]","mtarg1[9.04,46.8]","mtarg1[-27.12,46.8]","mtarg1[-27.12,78.0]","mtarg1[9.04,78.0]","mtarg1[45.19,78.0]","mtarg1[81.35,78.0]","mtarg1[81.35,109.2]","mtarg1[45.19,109.2]","mtarg1[9.04,109.2]","mtarg1[-27.12,109.2]","mtarg1[9.04,140.4]","mtarg1[9.04,171.6]","mtarg1[9.04,202.8]","mtarg1[153.65,234.0]","mtarg1[81.34,234.0]","mtarg1[45.19,234.0]","mtarg1[9.04,234.0]","mtarg1[9.04,265.2]","mtarg1[45.19,265.2]","mtarg1[81.34,265.2]","mtarg1[117.49,265.2]","mtarg1[117.49,296.4]","mtarg1[117.49,327.6]");
 
print "----- final flux and bandpass calibration -----\n";
  &DoFlux(flux1,nflux1);
  &DoPass(bpass1,nbpass1);

print "----- Congratulations!  This is the end of the script.  -----\n";}
#
################## File End ###############################

# %% [markdown]
# # OMC1_part2

# %%
oldstyle_loop_omc1_part2 = 'cal0,cal1,targ1,targ2,targ3,targ4,targ5,targ6,targ7,targ8,targ9,targ10,targ11,targ12,targ13,targ14,targ15,targ16,targ17,targ18,targ19,targ20,targ21,targ22,targ23,targ24,targ25,targ26,targ27,targ28,targ29,targ30,targ31,targ32,targ33,targ34,cal0,cal1,targ35,targ36,targ37,targ38,targ39,targ40,targ41,targ42,targ43,targ44,targ45,targ46,targ47,targ48,targ49,targ50,targ51,targ52,targ53,targ54,targ55,targ56,targ57,targ58,targ59,targ60,targ61,targ62,targ63,targ64,targ65,targ66,targ67,cal0,cal1,targ68,targ69,targ70,targ71,targ72,targ73,targ74,targ75,targ76,targ77,targ78,targ79,targ80,targ81,targ82,targ83,targ84,targ85,targ86,targ87,targ88,targ89,targ90,targ91,targ92,targ93,targ94,targ95,targ96,targ97,targ98,targ99,targ100,cal0,cal1,targ101,targ102,targ103,targ104,targ105,targ106,targ107,targ108,targ109,targ110,targ111,targ112,targ113,targ114,targ115,targ116,targ117,targ118,targ119,targ120,targ121,targ122,targ123,targ124,targ125,targ126,targ127,targ128,targ129,targ130,targ131,targ132,targ133,targ134,targ135'

print  "First target is: targ1; Last is targ128\n"
print  oldstyle_loop_omc1_part2, '\n' 

# splitting elements in loops as independent string variables
oldstyle_loop_omc1_part2_list = oldstyle_loop_omc1_part2.split(',')


print  'Loop 1 list \n' 
print  oldstyle_loop_omc1_part2_list
# Out:
# First target is: targ1; Last is targ128
#
# ...

# %%
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(0,34):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop2.csv'
jps_cat=ascii.read(jps_file)

for i in range(0,33):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop3.csv'
jps_cat=ascii.read(jps_file)

for i in range(0,33):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop4.csv'
jps_cat=ascii.read(jps_file)

for i in range(0,35):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for pnt_id in range( len(dec) ):
    print pnt_id + 1, ra[pnt_id], dec[pnt_id]
# Out:
# 1 83.8111111111 -5.42105379861
# 2 83.8011111111 -5.42105379861
# 3 83.7911111111 -5.41238713861
# 4 83.8011111111 -5.41238713861
# 5 83.8111111111 -5.41238713861
# 6 83.8211111111 -5.41238713861
# 7 83.8211111111 -5.40372047861
# 8 83.8111111111 -5.40372047861
# 9 83.8011111111 -5.40372047861
# 10 83.7911111111 -5.40372047861
# 11 83.7811111111 -5.39505381861
# 12 83.7911111111 -5.39505381861
# 13 83.8011111111 -5.39505381861
# 14 83.8111111111 -5.39505381861
# 15 83.8211111111 -5.39505381861
# 16 83.8411111111 -5.38638715861
# 17 83.8311111111 -5.38638715861
# 18 83.8211111111 -5.38638715861
# 19 83.8111111111 -5.38638715861
# 20 83.8011111111 -5.38638715861
# 21 83.7911111111 -5.38638715861
# 22 83.7811111111 -5.38638715861
# 23 83.7711111111 -5.37772049861
# 24 83.7811111111 -5.37772049861
# 25 83.7911111111 -5.37772049861
# 26 83.8011111111 -5.37772049861
# 27 83.8111111111 -5.37772049861
# 28 83.8211111111 -5.37772049861
# 29 83.8311111111 -5.37772049861
# ...

# %%
((5.42105379861-5)*60-25)*60
# Out:
# 15.793674996000107

# %% [markdown]
# Evaluating pointing offsets

# %%
raoffset_arcsec  =  np.arange( len(ra) ) * 0.0
decoffset_arcsec =  np.arange( len(ra) ) * 0.0

for pnt_id in range( len(dec) ):
    raoffset_arcsec[pnt_id]  = ( ra[pnt_id]  - ra[0] )  * 3600.0 \
                               / math.cos( dec[pnt_id] * (np.pi / 180.0) )
    decoffset_arcsec[pnt_id] = ( dec[pnt_id] - dec[0] ) * 3600.0
    

    
for pnt_id in range( len(dec) ):
    print pnt_id + 1, raoffset_arcsec[pnt_id],  decoffset_arcsec[pnt_id]
# Out:
# 1 0.0 0.0
# 2 -36.1617400169 0.0
# 3 -72.3224427068 31.199976
# 4 -36.1612213534 31.199976
# 5 0.0 31.199976
# 6 36.1612213534 31.199976
# 7 36.1607035321 62.399952
# 8 0.0 62.399952
# 9 -36.1607035321 62.399952
# 10 -72.3214070642 62.399952
# 11 -108.480559659 93.599928
# 12 -72.320373106 93.599928
# 13 -36.160186553 93.599928
# 14 0.0 93.599928
# 15 36.160186553 93.599928
# 16 108.479011248 124.799904
# 17 72.3193408319 124.799904
# 18 36.159670416 124.799904
# 19 0.0 124.799904
# 20 -36.159670416 124.799904
# 21 -72.3193408319 124.799904
# 22 -108.479011248 124.799904
# 23 -144.636620484 155.99988
# 24 -108.477465363 155.99988
# 25 -72.318310242 155.99988
# 26 -36.159155121 155.99988
# 27 0.0 155.99988
# 28 36.159155121 155.99988
# 29 72.318310242 155.99988
# 30 108.477465363 155.99988
# 31 144.636620484 155.99988
# 32 180.795775605 155.99988
# 33 144.634562672 187.199856
# 34 108.475922004 187.199856
# 35 18.0808700084 0.0
# 36 -18.0808700085 0.0
# 37 -54.2426100254 0.0
# ...

# %% [markdown]
# Constructing Looping command

# %%
# Constructing a dictionary between scan name and scan coordinate offset
offsetdict = {}
offsetdict['cal0'] = 'cal0'
offsetdict['cal1'] = 'cal1'
offsetdict['targ1'] = 'targ1'

for pnt_id in range(2, len(dec)+1 ):
    scan_name = 'targ' + str(pnt_id)
    offsetdict[scan_name] = '"m' + offsetdict['targ1'] \
                          + '[' + str( round(raoffset_arcsec[pnt_id  -1],2) ) + ','  \
                          +       str( round(decoffset_arcsec[pnt_id -1],2) ) + ']"'

omc1_part2_loop1 = "&ObsLoop("
for scan_id in range( len(oldstyle_loop_omc1_part2_list) ): 
    print oldstyle_loop_omc1_part2_list[scan_id], ' -> ', offsetdict[ oldstyle_loop_omc1_part2_list[scan_id] ] 
    omc1_part2_loop1 = omc1_part2_loop1 + offsetdict[ oldstyle_loop_omc1_part2_list[scan_id] ]
    if ( scan_id != (len(oldstyle_loop_omc1_part1_list) -1) ):
        omc1_part2_loop1 = omc1_part2_loop1 + ','
    else:
        omc1_part2_loop1 = omc1_part2_loop1 + ');'
# Out:
# cal0  ->  cal0
# cal1  ->  cal1
# targ1  ->  targ1
# targ2  ->  "mtarg1[-36.16,0.0]"
# targ3  ->  "mtarg1[-72.32,31.2]"
# targ4  ->  "mtarg1[-36.16,31.2]"
# targ5  ->  "mtarg1[0.0,31.2]"
# targ6  ->  "mtarg1[36.16,31.2]"
# targ7  ->  "mtarg1[36.16,62.4]"
# targ8  ->  "mtarg1[0.0,62.4]"
# targ9  ->  "mtarg1[-36.16,62.4]"
# targ10  ->  "mtarg1[-72.32,62.4]"
# targ11  ->  "mtarg1[-108.48,93.6]"
# targ12  ->  "mtarg1[-72.32,93.6]"
# targ13  ->  "mtarg1[-36.16,93.6]"
# targ14  ->  "mtarg1[0.0,93.6]"
# targ15  ->  "mtarg1[36.16,93.6]"
# targ16  ->  "mtarg1[108.48,124.8]"
# targ17  ->  "mtarg1[72.32,124.8]"
# targ18  ->  "mtarg1[36.16,124.8]"
# targ19  ->  "mtarg1[0.0,124.8]"
# targ20  ->  "mtarg1[-36.16,124.8]"
# targ21  ->  "mtarg1[-72.32,124.8]"
# targ22  ->  "mtarg1[-108.48,124.8]"
# targ23  ->  "mtarg1[-144.64,156.0]"
# targ24  ->  "mtarg1[-108.48,156.0]"
# targ25  ->  "mtarg1[-72.32,156.0]"
# targ26  ->  "mtarg1[-36.16,156.0]"
# targ27  ->  "mtarg1[0.0,156.0]"
# ...

# %%
print  "New format omc1_part2_loop1 \n" 
print  omc1_part2_loop1, '\n'
# Out:
# New format omc1_part2_loop1
#
# ...

# %%
# compact track for OMC1_part2

#!/usr/bin/perl -w
{ BEGIN {$^W =0}
#
################## Script Header Info #####################
#
# Experiment Code: 2018A-S028
# Experiment Title: Continuation of SMA Public Survey towards the Orion Molecular Cloud
# PI: Sihan Jiao
# Contact Person: Sihan Jiao / Baobab Liu
# Email  : sihanjiao@nao.cas.cn / baobabyoo@gmail.com
# Office : +86-18205095977  / +49 017643305521
# Home   : +86-18205095977   
# Array  : compact   
#
#
############## SPECIAL INSTRUCTIONS ################
#
# 1. Mosaic setup.
#    This is a mega mosaic project. 
#    Need help to execute in the way that Tsys is not
#    measured as often as switching field.
#
# 2. Timing
#    It will take approximately one hour to finish the loop.
#    For the mid night pointing, please wait until a loop is completed,
#    instead of breaking a loop to do pointing.
#
################## Priming ################################
#
# observe -s omc1 -r 05:35:20 -d -05:01:00 -e 2000 -v 10
# dopplerTrack -S omc1 -r 346 -u -s1 -f 0.0 -R B -r 344 -l -s1 -f 0.0
#
################## Pointing ###############################
#
# Pointing: At start and in middle of track
# Syntax Example: point -i 60 -r 3 -L -l -t -Q
#
################## Source, Calibrator and Limits ##########
#
$inttime="10"; 
$targ0="omc1 -r 05:35:15 -d -05:20:00 -e 2000 -v 10"; $ntarg0="2"; 

$targ1="omc1_targ1  -r 05:35:14.666666664002292 -d -05:25:15.793674996000107 -e 2000 -v 10"; $ntarg1="2";

$cal0="0433+053"; $ncal0="15";
$cal1="0501-019"; $ncal1="15";
$flux0="Uranus"; $nflux0="60";
$flux1="Callisto"; $nflux1="60";
$bpass0="3C84"; $nbpass0="400";
$bpass1="3C279"; $nbpass1="400";
$MINEL_TARG = 17; $MAXEL_TARG = 83;
$MINEL_GAIN = 17; $MAXEL_GAIN = 83;
$MINEL_FLUX = 17; $MAXEL_FLUX = 81;
$MINEL_BPASS= 17; $MAXEL_BPASS= 87;
$MINEL_CHECK= 19; 
#
################## Script Initialization ##################
#
do 'sma.pl';
do 'sma_add.pl';
checkANT();
command("radio");
command("integrate -t $inttime");
$myPID=$$;
command("project -r -p 'Sihan Jiao' -d '2018A-S028'");
print "----- initialization done, starting script -----\n";
#
################## Science Script #########################
#
print "----- initial flux and bandpass calibration -----\n";
if(!$restart){
  &DoPass(bpass0,nbpass0);
  &DoFlux(flux0,nflux0);
}

print "----- main science target observe loop -----\n";
&ObsLoop(cal0,cal1,targ1,"mtarg1[-36.16,0.0]","mtarg1[-72.32,31.2]","mtarg1[-36.16,31.2]","mtarg1[0.0,31.2]","mtarg1[36.16,31.2]","mtarg1[36.16,62.4]","mtarg1[0.0,62.4]","mtarg1[-36.16,62.4]","mtarg1[-72.32,62.4]","mtarg1[-108.48,93.6]","mtarg1[-72.32,93.6]","mtarg1[-36.16,93.6]","mtarg1[0.0,93.6]","mtarg1[36.16,93.6]","mtarg1[108.48,124.8]","mtarg1[72.32,124.8]","mtarg1[36.16,124.8]","mtarg1[0.0,124.8]","mtarg1[-36.16,124.8]","mtarg1[-72.32,124.8]","mtarg1[-108.48,124.8]","mtarg1[-144.64,156.0]","mtarg1[-108.48,156.0]","mtarg1[-72.32,156.0]","mtarg1[-36.16,156.0]","mtarg1[0.0,156.0]","mtarg1[36.16,156.0]","mtarg1[72.32,156.0]","mtarg1[108.48,156.0]","mtarg1[144.64,156.0]","mtarg1[180.8,156.0]","mtarg1[144.63,187.2]","mtarg1[108.48,187.2]",cal0,cal1,"mtarg1[18.08,0.0]","mtarg1[-18.08,0.0]","mtarg1[-54.24,0.0]","mtarg1[-54.24,31.2]","mtarg1[-18.08,31.2]","mtarg1[18.08,31.2]","mtarg1[54.24,62.4]","mtarg1[18.08,62.4]","mtarg1[-18.08,62.4]","mtarg1[-54.24,62.4]","mtarg1[-90.4,93.6]","mtarg1[-54.24,93.6]","mtarg1[-18.08,93.6]","mtarg1[18.08,93.6]","mtarg1[54.24,93.6]","mtarg1[90.4,124.8]","mtarg1[54.24,124.8]","mtarg1[18.08,124.8]","mtarg1[-18.08,124.8]","mtarg1[-54.24,124.8]","mtarg1[-90.4,124.8]","mtarg1[-126.56,124.8]","mtarg1[-162.72,156.0]","mtarg1[-126.56,156.0]","mtarg1[-90.4,156.0]","mtarg1[-54.24,156.0]","mtarg1[-18.08,156.0]","mtarg1[18.08,156.0]","mtarg1[54.24,156.0]","mtarg1[90.4,156.0]","mtarg1[126.56,156.0]","mtarg1[162.72,156.0]","mtarg1[162.71,187.2]",cal0,cal1,"mtarg1[27.12,15.6]","mtarg1[-9.04,15.6]","mtarg1[-45.2,15.6]","mtarg1[-45.2,46.8]","mtarg1[-9.04,46.8]","mtarg1[27.12,46.8]","mtarg1[63.28,78.0]","mtarg1[27.12,78.0]","mtarg1[-9.04,78.0]","mtarg1[-45.2,78.0]","mtarg1[-81.36,78.0]","mtarg1[-117.52,109.2]","mtarg1[-81.36,109.2]","mtarg1[-45.2,109.2]","mtarg1[-9.04,109.2]","mtarg1[27.12,109.2]","mtarg1[63.28,109.2]","mtarg1[99.44,140.4]","mtarg1[63.28,140.4]","mtarg1[27.12,140.4]","mtarg1[-9.04,140.4]","mtarg1[-45.2,140.4]","mtarg1[-81.36,140.4]","mtarg1[-117.52,140.4]","mtarg1[-153.68,140.4]","mtarg1[-81.36,171.6]","mtarg1[-45.2,171.6]","mtarg1[-9.04,171.6]","mtarg1[27.12,171.6]","mtarg1[63.28,171.6]","mtarg1[99.44,171.6]","mtarg1[135.6,171.6]","mtarg1[171.75,171.6]",cal0,cal1,"mtarg1[45.2,15.6]","mtarg1[9.04,15.6]","mtarg1[-27.12,15.6]","mtarg1[-63.28,15.6]","mtarg1[-63.28,46.8]","mtarg1[-27.12,46.8]","mtarg1[9.04,46.8]","mtarg1[45.2,46.8]","mtarg1[45.2,78.0]","mtarg1[9.04,78.0]","mtarg1[-27.12,78.0]","mtarg1[-63.28,78.0]","mtarg1[-99.44,78.0]","mtarg1[-99.44,109.2]","mtarg1[-63.28,109.2]","mtarg1[-27.12,109.2]","mtarg1[9.04,109.2]","mtarg1[45.2,109.2]","mtarg1[81.36,109.2]","mtarg1[81.36,140.4]","mtarg1[45.2,140.4]","mtarg1[9.04,140.4]","mtarg1[-27.12,140.4]","mtarg1[-63.28,140.4]","mtarg1[-99.44,140.4]","mtarg1[-135.6,140.4]","mtarg1[-63.28,171.6]","mtarg1[-27.12,171.6]");"mtarg1[9.04,171.6]","mtarg1[45.2,171.6]","mtarg1[81.36,171.6]","mtarg1[117.52,171.6]","mtarg1[153.68,171.6]","mtarg1[153.67,202.8]","mtarg1[117.51,202.8]",
 
print "----- final flux and bandpass calibration -----\n";
  &DoFlux(flux1,nflux1);
  &DoPass(bpass1,nbpass1);

print "----- Congratulations!  This is the end of the script.  -----\n";}
#
################## File End ###############################

# %% [markdown]
# # OMC1_part3

# %%
oldstyle_loop_omc1_part3 = 'cal0,cal1,targ1,targ2,targ3,targ4,targ5,targ6,targ7,targ8,targ9,targ10,targ11,targ12,targ13,targ14,targ15,targ16,targ17,targ18,targ19,targ20,targ21,targ22,targ23,targ24,targ25,targ26,targ27,targ28,targ29,targ30,targ31,targ32,targ33,cal0,cal1,targ34,targ35,targ36,targ37,targ38,targ39,targ40,targ41,targ42,targ43,targ44,targ45,targ46,targ47,targ48,targ49,targ50,targ51,targ52,targ53,targ54,targ55,targ56,targ57,targ58,targ59,targ60,targ61,targ62,targ63,targ64,targ65,targ66,cal0,cal1,targ67,targ68,targ69,targ70,targ71,targ72,targ73,targ74,targ75,targ76,targ77,targ78,targ79,targ80,targ81,targ82,targ83,targ84,targ85,targ86,targ87,targ88,targ89,targ90,targ91,targ92,targ93,targ94,targ95,targ96,targ97,targ98,targ99,targ100,cal0,cal1,targ101,targ102,targ103,targ104,targ105,targ106,targ107,targ108,targ109,targ110,targ111,targ112,targ113,targ114,targ115,targ116,targ117,targ118,targ119,targ120,targ121,targ122,targ123,targ124,targ125,targ126,targ127,targ128,targ129,targ130,targ131,targ132,targ133,targ134,targ135'

print  "First target is: targ1; Last is targ128\n"
print  oldstyle_loop_omc1_part3, '\n' 

# splitting elements in loops as independent string variables
oldstyle_loop_omc1_part3_list = oldstyle_loop_omc1_part3.split(',')


print  'Loop 1 list \n' 
print  oldstyle_loop_omc1_part3_list
# Out:
# First target is: targ1; Last is targ128
#
# ...

# %%
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(34,67):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop2.csv'
jps_cat=ascii.read(jps_file)

for i in range(33,66):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop3.csv'
jps_cat=ascii.read(jps_file)

for i in range(33,67):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop4.csv'
jps_cat=ascii.read(jps_file)

for i in range(35,70):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for pnt_id in range( len(dec) ):
    print pnt_id + 1, ra[pnt_id], dec[pnt_id]
# Out:
# 1 83.8311111111 -5.36905383861
# 2 83.8211111111 -5.36905383861
# 3 83.8111111111 -5.36905383861
# 4 83.8011111111 -5.36905383861
# 5 83.7911111111 -5.36905383861
# 6 83.7811111111 -5.36905383861
# 7 83.7811111111 -5.36038717861
# 8 83.7911111111 -5.36038717861
# 9 83.8011111111 -5.36038717861
# 10 83.8111111111 -5.36038717861
# 11 83.8211111111 -5.36038717861
# 12 83.8311111111 -5.36038717861
# 13 83.8411111111 -5.36038717861
# 14 83.8411111111 -5.35172051861
# 15 83.8311111111 -5.35172051861
# 16 83.8211111111 -5.35172051861
# 17 83.8111111111 -5.35172051861
# 18 83.8011111111 -5.35172051861
# 19 83.7911111111 -5.35172051861
# 20 83.7811111111 -5.35172051861
# 21 83.7711111111 -5.35172051861
# 22 83.7911111111 -5.34305385861
# 23 83.8011111111 -5.34305385861
# 24 83.8111111111 -5.34305385861
# 25 83.8211111111 -5.34305385861
# 26 83.8311111111 -5.34305385861
# 27 83.8511111111 -5.33438719861
# 28 83.8411111111 -5.33438719861
# 29 83.8311111111 -5.33438719861
# ...

# %%
((5.36905383861-5)*60-22)*60
# Out:
# 8.593818996000664

# %% [markdown]
# Evaluating pointing offsets

# %%
raoffset_arcsec  =  np.arange( len(ra) ) * 0.0
decoffset_arcsec =  np.arange( len(ra) ) * 0.0

for pnt_id in range( len(dec) ):
    raoffset_arcsec[pnt_id]  = ( ra[pnt_id]  - ra[0] )  * 3600.0 \
                               / math.cos( dec[pnt_id] * (np.pi / 180.0) )
    decoffset_arcsec[pnt_id] = ( dec[pnt_id] - dec[0] ) * 3600.0
    

    
for pnt_id in range( len(dec) ):
    print pnt_id + 1, raoffset_arcsec[pnt_id],  decoffset_arcsec[pnt_id]
# Out:
# 1 0.0 0.0
# 2 -36.158640668 0.0
# 3 -72.317281336 0.0
# 4 -108.475922004 0.0
# 5 -144.634562672 0.0
# 6 -180.79320334 0.0
# 7 -180.790635285 31.199976
# 8 -144.632508228 31.199976
# 9 -108.474381171 31.199976
# 10 -72.3162541139 31.199976
# 11 -36.158127057 31.199976
# 12 0.0 31.199976
# 13 36.158127057 31.199976
# 14 36.1576142878 62.399952
# 15 0.0 62.399952
# 16 -36.1576142878 62.399952
# 17 -72.3152285756 62.399952
# 18 -108.472842863 62.399952
# 19 -144.630457151 62.399952
# 20 -180.788071439 62.399952
# 21 -216.945685727 62.399952
# 22 -144.628409442 93.599928
# 23 -108.471307081 93.599928
# 24 -72.3142047209 93.599928
# 25 -36.1571023604 93.599928
# 26 0.0 93.599928
# 27 72.3131825496 124.799904
# 28 36.1565912748 124.799904
# 29 0.0 124.799904
# 30 -36.1565912748 124.799904
# 31 -72.3131825496 124.799904
# 32 -108.469773824 124.799904
# 33 -144.626365099 124.799904
# 34 54.237961002 0.0
# 35 18.079320334 0.0
# 36 -18.079320334 0.0
# 37 -54.2379610021 0.0
# ...

# %% [markdown]
# Constructing Looping command

# %%
# Constructing a dictionary between scan name and scan coordinate offset
offsetdict = {}
offsetdict['cal0'] = 'cal0'
offsetdict['cal1'] = 'cal1'
offsetdict['targ1'] = 'targ1'

for pnt_id in range(2, len(dec)+1 ):
    scan_name = 'targ' + str(pnt_id)
    offsetdict[scan_name] = '"m' + offsetdict['targ1'] \
                          + '[' + str( round(raoffset_arcsec[pnt_id  -1],2) ) + ','  \
                          +       str( round(decoffset_arcsec[pnt_id -1],2) ) + ']"'

omc1_part3_loop1 = "&ObsLoop("
for scan_id in range( len(oldstyle_loop_omc1_part3_list) ): 
    print oldstyle_loop_omc1_part3_list[scan_id], ' -> ', offsetdict[ oldstyle_loop_omc1_part3_list[scan_id] ] 
    omc1_part3_loop1 = omc1_part3_loop1 + offsetdict[ oldstyle_loop_omc1_part3_list[scan_id] ]
    if ( scan_id != (len(oldstyle_loop_omc1_part3_list) -1) ):
        omc1_part3_loop1 = omc1_part3_loop1 + ','
    else:
        omc1_part3_loop1 = omc1_part3_loop1 + ');'
# Out:
# cal0  ->  cal0
# cal1  ->  cal1
# targ1  ->  targ1
# targ2  ->  "mtarg1[-36.16,0.0]"
# targ3  ->  "mtarg1[-72.32,0.0]"
# targ4  ->  "mtarg1[-108.48,0.0]"
# targ5  ->  "mtarg1[-144.63,0.0]"
# targ6  ->  "mtarg1[-180.79,0.0]"
# targ7  ->  "mtarg1[-180.79,31.2]"
# targ8  ->  "mtarg1[-144.63,31.2]"
# targ9  ->  "mtarg1[-108.47,31.2]"
# targ10  ->  "mtarg1[-72.32,31.2]"
# targ11  ->  "mtarg1[-36.16,31.2]"
# targ12  ->  "mtarg1[0.0,31.2]"
# targ13  ->  "mtarg1[36.16,31.2]"
# targ14  ->  "mtarg1[36.16,62.4]"
# targ15  ->  "mtarg1[0.0,62.4]"
# targ16  ->  "mtarg1[-36.16,62.4]"
# targ17  ->  "mtarg1[-72.32,62.4]"
# targ18  ->  "mtarg1[-108.47,62.4]"
# targ19  ->  "mtarg1[-144.63,62.4]"
# targ20  ->  "mtarg1[-180.79,62.4]"
# targ21  ->  "mtarg1[-216.95,62.4]"
# targ22  ->  "mtarg1[-144.63,93.6]"
# targ23  ->  "mtarg1[-108.47,93.6]"
# targ24  ->  "mtarg1[-72.31,93.6]"
# targ25  ->  "mtarg1[-36.16,93.6]"
# targ26  ->  "mtarg1[0.0,93.6]"
# targ27  ->  "mtarg1[72.31,124.8]"
# ...

# %%
print  "New format omc1_part3_loop1 \n" 
print  omc1_part3_loop1, '\n'
# Out:
# New format omc1_part3_loop1
#
# ...

# %%
# compact track for OMC1_part3

#!/usr/bin/perl -w
{ BEGIN {$^W =0}
#
################## Script Header Info #####################
#
# Experiment Code: 2018A-S028
# Experiment Title: Continuation of SMA Public Survey towards the Orion Molecular Cloud
# PI: Sihan Jiao
# Contact Person: Sihan Jiao / Baobab Liu
# Email  : sihanjiao@nao.cas.cn / baobabyoo@gmail.com
# Office : +86-18205095977  / +49 017643305521
# Home   : +86-18205095977   
# Array  : compact   
#
#
############## SPECIAL INSTRUCTIONS ################
#
# 1. Mosaic setup.
#    This is a mega mosaic project. 
#    Need help to execute in the way that Tsys is not
#    measured as often as switching field.
#
# 2. Timing
#    It will take approximately one hour to finish the loop.
#    For the mid night pointing, please wait until a loop is completed,
#    instead of breaking a loop to do pointing.
#
################## Priming ################################
#
# observe -s omc1 -r 05:35:20 -d -05:01:00 -e 2000 -v 10
# dopplerTrack -S omc1 -r 346 -u -s1 -f 0.0 -R B -r 344 -l -s1 -f 0.0
#
################## Pointing ###############################
#
# Pointing: At start and in middle of track
# Syntax Example: point -i 60 -r 3 -L -l -t -Q
#
################## Source, Calibrator and Limits ##########
#
$inttime="10"; 
$targ0="omc1 -r 05:35:15 -d -05:20:00 -e 2000 -v 10"; $ntarg0="2"; 

$targ1="omc1_targ1  -r 05:35:19.466666663998353 -d -05:22:08.593818996000664 -e 2000 -v 10"; $ntarg1="2";

$cal0="0433+053"; $ncal0="15";
$cal1="0501-019"; $ncal1="15";
$flux0="Uranus"; $nflux0="60";
$flux1="Callisto"; $nflux1="60";
$bpass0="3C84"; $nbpass0="400";
$bpass1="3C279"; $nbpass1="400";
$MINEL_TARG = 17; $MAXEL_TARG = 83;
$MINEL_GAIN = 17; $MAXEL_GAIN = 83;
$MINEL_FLUX = 17; $MAXEL_FLUX = 81;
$MINEL_BPASS= 17; $MAXEL_BPASS= 87;
$MINEL_CHECK= 19; 
#
################## Script Initialization ##################
#
do 'sma.pl';
do 'sma_add.pl';
checkANT();
command("radio");
command("integrate -t $inttime");
$myPID=$$;
command("project -r -p 'Sihan Jiao' -d '2018A-S028'");
print "----- initialization done, starting script -----\n";
#
################## Science Script #########################
#
print "----- initial flux and bandpass calibration -----\n";
if(!$restart){
  &DoPass(bpass0,nbpass0);
  &DoFlux(flux0,nflux0);
}

print "----- main science target observe loop -----\n";
&ObsLoop(cal0,cal1,targ1,"mtarg1[-36.16,0.0]","mtarg1[-72.32,0.0]","mtarg1[-108.48,0.0]","mtarg1[-144.63,0.0]","mtarg1[-180.79,0.0]","mtarg1[-180.79,31.2]","mtarg1[-144.63,31.2]","mtarg1[-108.47,31.2]","mtarg1[-72.32,31.2]","mtarg1[-36.16,31.2]","mtarg1[0.0,31.2]","mtarg1[36.16,31.2]","mtarg1[36.16,62.4]","mtarg1[0.0,62.4]","mtarg1[-36.16,62.4]","mtarg1[-72.32,62.4]","mtarg1[-108.47,62.4]","mtarg1[-144.63,62.4]","mtarg1[-180.79,62.4]","mtarg1[-216.95,62.4]","mtarg1[-144.63,93.6]","mtarg1[-108.47,93.6]","mtarg1[-72.31,93.6]","mtarg1[-36.16,93.6]","mtarg1[0.0,93.6]","mtarg1[72.31,124.8]","mtarg1[36.16,124.8]","mtarg1[0.0,124.8]","mtarg1[-36.16,124.8]","mtarg1[-72.31,124.8]","mtarg1[-108.47,124.8]","mtarg1[-144.63,124.8]",cal0,cal1,"mtarg1[54.24,0.0]","mtarg1[18.08,0.0]","mtarg1[-18.08,0.0]","mtarg1[-54.24,0.0]","mtarg1[-90.4,0.0]","mtarg1[-126.56,0.0]","mtarg1[-162.71,0.0]","mtarg1[-162.71,31.2]","mtarg1[-126.55,31.2]","mtarg1[-90.4,31.2]","mtarg1[-54.24,31.2]","mtarg1[-18.08,31.2]","mtarg1[18.08,31.2]","mtarg1[18.08,62.4]","mtarg1[-18.08,62.4]","mtarg1[-54.24,62.4]","mtarg1[-90.39,62.4]","mtarg1[-126.55,62.4]","mtarg1[-162.71,62.4]","mtarg1[-198.87,62.4]","mtarg1[-162.71,93.6]","mtarg1[-126.55,93.6]","mtarg1[-90.39,93.6]","mtarg1[-54.24,93.6]","mtarg1[-18.08,93.6]","mtarg1[18.08,93.6]","mtarg1[90.39,124.8]","mtarg1[54.23,124.8]","mtarg1[18.08,124.8]","mtarg1[-18.08,124.8]","mtarg1[-54.23,124.8]","mtarg1[-90.39,124.8]","mtarg1[-162.7,124.8]",cal0,cal1,"mtarg1[27.12,15.6]","mtarg1[-9.04,15.6]","mtarg1[-45.2,15.6]","mtarg1[-81.36,15.6]","mtarg1[-117.51,15.6]","mtarg1[-153.67,15.6]","mtarg1[-189.83,15.6]","mtarg1[-225.99,46.8]","mtarg1[-189.83,46.8]","mtarg1[-153.67,46.8]","mtarg1[-117.51,46.8]","mtarg1[-81.36,46.8]","mtarg1[-45.2,46.8]","mtarg1[-9.04,46.8]","mtarg1[27.12,46.8]","mtarg1[27.12,78.0]","mtarg1[-9.04,78.0]","mtarg1[-45.2,78.0]","mtarg1[-81.35,78.0]","mtarg1[-117.51,78.0]","mtarg1[-153.67,78.0]","mtarg1[-153.67,109.2]","mtarg1[-117.51,109.2]","mtarg1[-81.35,109.2]","mtarg1[-45.2,109.2]","mtarg1[-9.04,109.2]","mtarg1[27.12,109.2]","mtarg1[63.27,109.2]","mtarg1[99.43,109.2]","mtarg1[63.27,140.4]","mtarg1[27.12,140.4]","mtarg1[-9.04,140.4]","mtarg1[-45.2,140.4]","mtarg1[-81.35,140.4]",cal0,cal1,"mtarg1[9.04,15.6]","mtarg1[-27.12,15.6]","mtarg1[-63.28,15.6]","mtarg1[-99.44,15.6]","mtarg1[-135.59,15.6]","mtarg1[-171.75,15.6]","mtarg1[-207.91,46.8]","mtarg1[-171.75,46.8]","mtarg1[-135.59,46.8]","mtarg1[-99.43,46.8]","mtarg1[-63.28,46.8]","mtarg1[-27.12,46.8]","mtarg1[9.04,46.8]","mtarg1[45.2,46.8]","mtarg1[9.04,78.0]","mtarg1[-27.12,78.0]","mtarg1[-63.28,78.0]","mtarg1[-99.43,78.0]","mtarg1[-135.59,78.0]","mtarg1[-171.75,78.0]","mtarg1[-171.75,109.2]","mtarg1[-99.43,109.2]","mtarg1[-63.27,109.2]","mtarg1[-27.12,109.2]","mtarg1[9.04,109.2]","mtarg1[45.2,109.2]","mtarg1[81.35,109.2]","mtarg1[117.51,109.2]","mtarg1[81.35,140.4]","mtarg1[45.2,140.4]","mtarg1[9.04,140.4]","mtarg1[-27.12,140.4]","mtarg1[-63.27,140.4]","mtarg1[-99.43,140.4]","mtarg1[-171.74,140.4]");
 
print "----- final flux and bandpass calibration -----\n";
  &DoFlux(flux1,nflux1);
  &DoPass(bpass1,nbpass1);

print "----- Congratulations!  This is the end of the script.  -----\n";}
#
################## File End ###############################
