# %% [markdown]
# # OMC1/3_SMAmegaMosaic

# %%
import matplotlib
from astropy import units as u
import aplpy
import numpy as np
import astropy.io.fits as fits
from astropy.io import ascii
from astropy.table import Column, Table
# %matplotlib inline

# %% [markdown]
# # OMC3

# %% [markdown]
# We will use 4 loops in one track to mosaic omc3, and each loop can cover the target region. Following the sequence of pointings in the track, after doing calibration everytime we will cover the whole region once (one loop) for visiting every location within our mosaic area approximately every 15~20 mins.

# %% [markdown]
# All pointings in the track (34+35+33+32=134 pointings in total)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.835,-5.005669,width=0.15,height=0.2)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop1 in the track (34 pointings), the blue arrows show the scan sequence.

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.835,-5.005669,width=0.15,height=0.2)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

combined = np.vstack((ra, dec)).T

#for i in range(0,len(ra)-1):
#    x = np.array([[ra[i]],[dec[i]]])
#    y = np.array([[ra[i+1]],[dec[i+1]]])
#    f.show_lines([x, y],color='r',linestyle='-',linewidth=1)
    #print x,y



f.show_arrows(ra[1],dec[1],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[0],dec[0],-0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[2],dec[2],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[3],dec[3],-0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[4],dec[4],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[5],dec[5],-0.009,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[6],dec[6],-0.009,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[7],dec[7],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[8],dec[8],0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)
for i in range(9,12):
    f.show_arrows(ra[i],dec[i],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[12],dec[12],0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)
for i in range(13,16):
    f.show_arrows(ra[i],dec[i],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[16],dec[16],-0.018,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[17],dec[17],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[18],dec[18],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[19],dec[19],-0.018,0.009,width=0.5,head_width=1.1,head_length=1.5)
for i in range(20,24):
    f.show_arrows(ra[i],dec[i],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[24],dec[24],-0.018,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[25],dec[25],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[26],dec[26],-0.009,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[27],dec[27],0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[28],dec[28],0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[29],dec[29],-0.009,0.00,width=0.5,head_width=1.1,head_length=1.5)
f.show_arrows(ra[30],dec[30],-0.00,0.009,width=0.5,head_width=1.1,head_length=1.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop2 in the track (35 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.835,-5.005669,width=0.15,height=0.2)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop3 in the track (33 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.835,-5.005669,width=0.15,height=0.2)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop4 in the track (32 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.835,-5.005669,width=0.15,height=0.2)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc3_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# # OMC1

# %% [markdown]
# We will use 3 tracks to mosaic omc1, and each track have 4 loops covering the target region. And in the same way,  following the sequence of pointings in the track, after doing calibration everytime we will cover the whole region once (one loop) for visiting every location within our mosaic area approximately every 15~20 mins.

# %% [markdown]
# # OMC1-part1 (1 track)

# %% [markdown]
# All pointings in the track (37+34+33+32=136 pointings in total)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop1 in the track (37 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop2 in the track (34 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop3 in the track (33 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# Loop4 in the track (32 pointings)

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part1_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# # OMC1-part2 (2 tracks)

# %% [markdown]
# We will use 2 tracks to map this region with 69+68+69+72=414 pointings in total

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)
    
jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# "Loop1" (69 pointings), and it will be divided into 2 loops

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop1.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# "Loop2" (68 pointings), and it will be divided into 2 loops

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop2.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# "Loop3" (69 pointings), and it will be divided into 2 loops

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop3.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]

# %% [markdown]
# "Loop4" (72 pointings), and it will be divided into 2 loops

# %%
f = aplpy.FITSFigure('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', figsize=(10,10))
f.show_grayscale()

f.add_colorbar()
f.colorbar.show()

f.recenter(83.805,-5.34669,width=0.2,height=0.3)
#f.recenter(83.855,-5.14669,width=0.15,height=0.2)

f.colorbar.set_location('top')
f.colorbar.set_axis_label_text(r'Flux (Jy beam$^{-1}$)')
f.show_colorscale(vmax=0.25,cmap='gist_yarg',stretch='arcsinh')
f.colorbar.set_width(0.15)
f.colorbar.set_ticks([0.05,0.1,0.2])
f.add_beam(major=14.0*u.arcsecond,minor=14.0*u.arcsecond,angle=0.0)
f.add_label(0.17, 0.06, 'Beam: 14.0\"', relative=True, size='large', layer='title',color='black')
f.show_contour('/Users/shjiao/documents/orion/sedlarge/plot/proposal/orion_sma.fits', levels=[0.03], colors='orange',linewidths=1)

jps_file='/Users/shjiao/desktop/za/sma_pointing/omc1_part2_loop4.csv'
jps_cat=ascii.read(jps_file)

ra=[]
dec=[]
for i in range(len(jps_cat)):
    ra.append(jps_cat['col0'][i])
    dec.append(jps_cat['col1'][i])

for i in range(0,len(ra)):
    f.show_circles(float(ra[i]),float(dec[i]), 0.005,edgecolors='lime',linewidths=0.5)

f.tick_labels.set_font(size='large')
f.axis_labels.set_font(size='large')
# Out:
# INFO: Auto-setting vmin to -2.495e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.143e-01 [aplpy.core]
# INFO: Auto-setting vmin to -5.176e-03 [aplpy.core]
